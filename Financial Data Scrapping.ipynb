# %%
! pip install demjson
! pip install xlsxwriter
import json
import urllib.request
import pandas as pd
import numpy as np
import demjson
import xlsxwriter
# Out:
# Requirement already satisfied: demjson in /usr/local/lib/python3.6/dist-packages (2.2.4)
# Collecting xlsxwriter
#   Downloading https://files.pythonhosted.org/packages/2b/98/17875723b6814fc4d0fc03f0997ee00de2dbd78cf195e2ec3f2c9c789d40/XlsxWriter-1.3.3-py2.py3-none-any.whl (144kB)
#      |████████████████████████████████| 153kB 3.4MB/s
# Installing collected packages: xlsxwriter
# Successfully installed xlsxwriter-1.3.3

# %%
def scrapping_eastmoney_kcb_single_year(statement, year, page_numbers):

  data_df_year = pd.DataFrame()

  for page_number in page_numbers:

    print("scrapping data in page {}".format(page_number))

    if statement == "BS":
      url = "http://datacenter.eastmoney.com/api/data/get?type=RPT_DMSK_FN_BALANCE&sty=ALL&p={}" \
            "&ps=50&st=NOTICE_DATE,SECURITY_CODE&sr=-1,-1&var=VqQfOphg&filter=(SECURITY_TYPE_CODE=%22058001001%22)" \
            "(TRADE_MARKET_CODE=%22069001001006%22)(REPORT_DATE=%27{}-12-31%27)&rt=53280464".format(str(page_number), str(year))
    elif statement == "PL":
      url = "http://datacenter.eastmoney.com/api/data/get?type=RPT_DMSK_FN_INCOME&sty=ALL&p={}" \
            "&ps=50&st=NOTICE_DATE,SECURITY_CODE&sr=-1,-1&var=moDdrKXO&filter=(SECURITY_TYPE_CODE=%22058001001%22)" \
            "(TRADE_MARKET_CODE=%22069001001006%22)(REPORT_DATE=%27{}-12-31%27)&rt=53280464".format(str(page_number), str(year))
    elif statement == "RP":
      url = "http://datacenter.eastmoney.com/api/data/get?type=RPT_LICO_FN_CPD&sty=ALL&p={}" \
            "&ps=50&st=UPDATE_DATE,SECURITY_CODE&sr=-1,-1&var=lRYCxRdi&filter=(SECURITY_TYPE_CODE=%22058001001%22)" \
            "(TRADE_MARKET_CODE=%22069001001006%22)(REPORTDATE=%27{}-12-31%27)&rt=53280464".format(str(page_number), str(year))
    else:
      raise Exception("Plese use 'BS' for balance sheet or 'PL' for income statement or 'RP' for achievement report")

    wp = urllib.request.urlopen(url)
    data = wp.read().decode("utf -8", "ignore")
    start_pos = data.index("=")
    json_data = demjson.encode(data[start_pos+1:(-1)])
    dicti = json.loads(json.loads(json_data))

    if str(dicti["result"]) == "None":
      break
    
    if statement == "BS":
      data_df_page = pd.DataFrame(dicti["result"]["data"])[["SECURITY_CODE","SECURITY_NAME_ABBR","INDUSTRY_NAME","ACCOUNTS_RECE","INVENTORY","TOTAL_EQUITY","CURRENT_RATIO","DEBT_ASSET_RATIO"]]

      print("sample page {} data\n{}".format(page_number, data_df_page.head()))

    elif statement == "PL":
      data_df_page = pd.DataFrame(dicti["result"]["data"])[["SECURITY_CODE","PARENT_NETPROFIT","TOTAL_OPERATE_INCOME","OPERATE_PROFIT_RATIO"]]

      print("sample page {} data\n{}".format(page_number, data_df_page.head()))

    else:
      data_df_page = pd.DataFrame(dicti["result"]["data"])[["SECURITY_CODE","WEIGHTAVG_ROE","XSMLL"]]

      print("sample page {} data\n{}".format(page_number, data_df_page.head()))

    data_df_year = data_df_year.append(data_df_page)

  print("sample year {} data\n{}".format(year, data_df_year.head()))
  
  return data_df_year

# %%
def scrapping_eastmoney_kcb_multiple_years(statement, years, page_numbers):

  data_df_statement = pd.DataFrame()

  for year in years:

    print("scrapping year {} data".format(year))

    data_df_year = scrapping_eastmoney_kcb_single_year(statement, year, page_numbers)
    data_df_year["year"] = year
    data_df_statement = data_df_statement.append(data_df_year)
  
  print("sample {}-{} data\n{}".format(years[0], years[-1], data_df_statement.head()))
  
  return data_df_statement

# %%
def scrapping_eastmoney_kcb_multiple_statements(years, page_numbers):

  print("scrapping balance sheet data")

  data_df_bs = scrapping_eastmoney_kcb_multiple_years("BS", years, page_numbers)

  print("scrapping income statement data")

  data_df_pl = scrapping_eastmoney_kcb_multiple_years("PL", years, page_numbers)

  print("scrapping achievement report data")

  data_df_rp = scrapping_eastmoney_kcb_multiple_years("RP", years, page_numbers)

  df_data =  pd.merge(data_df_bs, data_df_pl, on=["SECURITY_CODE", "year"])
  df_data =  pd.merge(df_data, data_df_rp, on=["SECURITY_CODE", "year"])

  print("sample combined statements data\n{}".format(df_data.head()))

  return df_data.sort_values(by=["year", "SECURITY_CODE"], ascending=[False, True])

# %%
def calculate_indicators(df_data):

  df_data = df_data.dropna(axis=0, how="any")

  df_data["COGS"] = df_data["TOTAL_OPERATE_INCOME"] * (1 - df_data["XSMLL"]/100)

  df_data_indicators_complete = pd.DataFrame()
  
  indicator_writer = pd.ExcelWriter("/content/sample_data/indicators.xlsx", engine="xlsxwriter")

  for year in sorted(list(set(list(df_data["year"])))):
    
    print("calculating year {} indicators".format(year))

    df_data_beginning = df_data[df_data["year"]==year-1][["SECURITY_CODE", "INVENTORY", "ACCOUNTS_RECE"]].rename(columns={"INVENTORY":"beginning_inventory", "ACCOUNTS_RECE":"beginning_accounts_rece"})
    df_data_year = pd.merge(df_data[df_data["year"]==year-1], df_data_beginning, on="SECURITY_CODE")

    df_data_year["inventory_turnover"] = df_data_year["COGS"] *2 / (df_data_year["beginning_inventory"] + df_data_year["INVENTORY"])
    df_data_year["accounts_rece_turnover"] = df_data_year["TOTAL_OPERATE_INCOME"] * 2 / (df_data_year["ACCOUNTS_RECE"] + df_data_year["beginning_accounts_rece"])

    df_data_year = df_data_year[["SECURITY_CODE","SECURITY_NAME_ABBR","INDUSTRY_NAME","year","OPERATE_PROFIT_RATIO","WEIGHTAVG_ROE","CURRENT_RATIO","DEBT_ASSET_RATIO","accounts_rece_turnover","inventory_turnover"]]
    
    df_data_year.to_excel(indicator_writer, sheet_name=str(year), index=False)

    df_data_indicators_complete = df_data_indicators_complete.append(df_data_year)

  indicator_writer.save()
  indicator_writer.close()

  return df_data_indicators_complete

# %%
def normalization(df_data):
  
  indicator_normalized_writer = pd.ExcelWriter("/content/sample_data/indicators_normalized.xlsx", engine="xlsxwriter")

  df_data_normalized_complete = pd.DataFrame()

  for year in sorted(list(set(list(df_data["year"])))):
    df_data_year = df_data[df_data["year"]==year]

    df_data_year["OPERATE_PROFIT_RATIO_normalized"] = (df_data_year["OPERATE_PROFIT_RATIO"] - min(df_data_year["OPERATE_PROFIT_RATIO"]) + np.exp(-10)) / (max(df_data_year["OPERATE_PROFIT_RATIO"]) - min(df_data_year["OPERATE_PROFIT_RATIO"]))
    df_data_year["WEIGHTAVG_ROE_normalized"] = (df_data_year["WEIGHTAVG_ROE"] - min(df_data_year["WEIGHTAVG_ROE"]) + np.exp(-10)) / (max(df_data_year["WEIGHTAVG_ROE"]) - min(df_data_year["WEIGHTAVG_ROE"]))
    df_data_year["CURRENT_RATIO_normalized"] = (df_data_year["CURRENT_RATIO"] - min(df_data_year["CURRENT_RATIO"]) + np.exp(-10)) / (max(df_data_year["CURRENT_RATIO"]) - min(df_data_year["CURRENT_RATIO"]))
    df_data_year["DEBT_ASSET_RATIO_normalized"] = (max(df_data_year["DEBT_ASSET_RATIO"]) - df_data_year["DEBT_ASSET_RATIO"] + np.exp(-10)) / (max(df_data_year["DEBT_ASSET_RATIO"]) - min(df_data_year["DEBT_ASSET_RATIO"]))
    df_data_year["accounts_rece_turnover_normalized"] = (df_data_year["accounts_rece_turnover"] - min(df_data_year["accounts_rece_turnover"]) + np.exp(-10)) / (max(df_data_year["accounts_rece_turnover"]) - min(df_data_year["accounts_rece_turnover"]))
    df_data_year["inventory_turnover_normalized"] = (df_data_year["inventory_turnover"] - min(df_data_year["inventory_turnover"]) + np.exp(-10)) / (max(df_data_year["inventory_turnover"]) - min(df_data_year["inventory_turnover"]))

    df_data_year = df_data_year[["SECURITY_CODE","year","OPERATE_PROFIT_RATIO_normalized","WEIGHTAVG_ROE_normalized","CURRENT_RATIO_normalized","DEBT_ASSET_RATIO_normalized","accounts_rece_turnover_normalized","inventory_turnover_normalized"]]
    df_data_year.to_excel(indicator_normalized_writer, sheet_name=str(year), index=False)

    df_data_normalized_complete = df_data_normalized_complete.append(df_data_year)

  indicator_normalized_writer.save()
  indicator_normalized_writer.close()

  return pd.merge(df_data, df_data_normalized_complete, on=["SECURITY_CODE", "year"])

# %%
def calculate_weights(df_data):
  
  indicator_weights_writer = pd.ExcelWriter("/content/sample_data/indicators_weight.xlsx", engine="xlsxwriter")

  df_data_weights_complete = pd.DataFrame()

  for year in sorted(list(set(list(df_data["year"])))):
    df_data_year = df_data[df_data["year"]==year]
    
    df_data_year["OPERATE_PROFIT_RATIO_weight"] = df_data_year["OPERATE_PROFIT_RATIO_normalized"] / sum(df_data_year["OPERATE_PROFIT_RATIO_normalized"])
    df_data_year["WEIGHTAVG_ROE_weight"] = df_data_year["WEIGHTAVG_ROE_normalized"] / sum(df_data_year["WEIGHTAVG_ROE_normalized"])
    df_data_year["CURRENT_RATIO_weight"] = df_data_year["CURRENT_RATIO_normalized"] / sum(df_data_year["CURRENT_RATIO_normalized"])
    df_data_year["DEBT_ASSET_RATIO_weight"] = df_data_year["DEBT_ASSET_RATIO_normalized"] / sum(df_data_year["DEBT_ASSET_RATIO_normalized"])
    df_data_year["accounts_rece_turnover_weight"] = df_data_year["accounts_rece_turnover_normalized"] / sum(df_data_year["accounts_rece_turnover_normalized"])
    df_data_year["inventory_turnover_weight"] = df_data_year["inventory_turnover_normalized"] / sum(df_data_year["inventory_turnover_normalized"])

    df_data_year = df_data_year[["SECURITY_CODE","year","OPERATE_PROFIT_RATIO_weight","WEIGHTAVG_ROE_weight","CURRENT_RATIO_weight","DEBT_ASSET_RATIO_weight","accounts_rece_turnover_weight","inventory_turnover_weight"]]
    df_data_year.to_excel(indicator_weights_writer, sheet_name=str(year), index=False)

    df_data_weights_complete = df_data_weights_complete.append(df_data_year)

  indicator_weights_writer.save()
  indicator_weights_writer.close()
  
  return pd.merge(df_data, df_data_weights_complete, on=["SECURITY_CODE", "year"])

# %%
def calculate_shang(df_data):

  shang_writer = pd.ExcelWriter("/content/sample_data/shang.xlsx", engine="xlsxwriter")
  df_data_shang_complete = pd.DataFrame()

  for year in sorted(list(set(list(df_data["year"])))):
    df_data_year = df_data[df_data["year"]==year]
    n = len(df_data_year.index)
    OPERATE_PROFIT_RATIO_shang_rong = 1 + 1 / np.log(n) * sum(df_data_year["OPERATE_PROFIT_RATIO_normalized"] * np.log(df_data_year["OPERATE_PROFIT_RATIO_normalized"]))
    WEIGHTAVG_ROE_shang_rong = 1 + 1 / np.log(n) * sum(df_data_year["WEIGHTAVG_ROE_normalized"] * np.log(df_data_year["WEIGHTAVG_ROE_normalized"]))
    CURRENT_RATIO_shang_rong = 1 + 1 / np.log(n) * sum(df_data_year["CURRENT_RATIO_normalized"] * np.log(df_data_year["CURRENT_RATIO_normalized"]))
    DEBT_ASSET_RATIO_shang_rong = 1 + 1 / np.log(n) * sum(df_data_year["DEBT_ASSET_RATIO_normalized"] * np.log(df_data_year["DEBT_ASSET_RATIO_normalized"]))
    accounts_rece_turnover_shang_rong = 1 + 1 / np.log(n) * sum(df_data_year["accounts_rece_turnover_normalized"] * np.log(df_data_year["accounts_rece_turnover_normalized"]))
    inventory_turnover_shang_rong = 1 + 1 / np.log(n) * sum(df_data_year["inventory_turnover_normalized"] * np.log(df_data_year["inventory_turnover_normalized"]))
    print(n)
    print(np.log(df_data_year["OPERATE_PROFIT_RATIO_normalized"]))
    print(sum(df_data_year["OPERATE_PROFIT_RATIO_normalized"] * np.log(df_data_year["OPERATE_PROFIT_RATIO_normalized"])))
    print(1 / np.log(n) * sum(df_data_year["OPERATE_PROFIT_RATIO_normalized"] * np.log(df_data_year["OPERATE_PROFIT_RATIO_normalized"])))
    print("WEIGHTAVG_ROE_shang_rong: {}".format(WEIGHTAVG_ROE_shang_rong))
    total_weight = OPERATE_PROFIT_RATIO_shang_rong + WEIGHTAVG_ROE_shang_rong + CURRENT_RATIO_shang_rong + DEBT_ASSET_RATIO_shang_rong + accounts_rece_turnover_shang_rong + inventory_turnover_shang_rong
    OPERATE_PROFIT_RATIO_weight = OPERATE_PROFIT_RATIO_shang_rong / total_weight
    WEIGHTAVG_ROE_weight = WEIGHTAVG_ROE_shang_rong / total_weight
    CURRENT_RATIO_weight =  CURRENT_RATIO_shang_rong / total_weight
    DEBT_ASSET_RATIO_weight = DEBT_ASSET_RATIO_shang_rong / total_weight
    accounts_rece_turnover_weight = accounts_rece_turnover_shang_rong / total_weight
    inventory_turnover_weight = inventory_turnover_shang_rong / total_weight

    df_data_year["shang"] = OPERATE_PROFIT_RATIO_weight * df_data_year["OPERATE_PROFIT_RATIO_weight"] + WEIGHTAVG_ROE_weight * df_data_year["WEIGHTAVG_ROE_weight"] + \
                                CURRENT_RATIO_weight * df_data_year["CURRENT_RATIO_weight"] + DEBT_ASSET_RATIO_weight * df_data_year["DEBT_ASSET_RATIO_weight"] + \
                                accounts_rece_turnover_weight * df_data_year["accounts_rece_turnover_weight"] + inventory_turnover_weight * df_data_year["inventory_turnover_weight"]
    
    df_data_shang_complete = df_data_shang_complete.append(df_data_year[["SECURITY_CODE","SECURITY_NAME_ABBR","INDUSTRY_NAME","year","shang"]])
  
  df_data_shang_complete.sort_values(by=["SECURITY_CODE", "year"]).to_excel(shang_writer, index=False)

  shang_writer.save()
  shang_writer.close()

# %%
def main():
  DfData = scrapping_eastmoney_kcb_multiple_statements(range(2010, 2020), range(1, 5))
  DfData = calculate_indicators(DfData)
  DfData = normalization(DfData)
  DfData = calculate_weights(DfData)
  calculate_shang(DfData)

# %%
main()
# Out:
# scrapping balance sheet data
# scrapping year 2010 data
# scrapping data in page 1
# sample page 1 data
#   SECURITY_CODE SECURITY_NAME_ABBR  ... CURRENT_RATIO  DEBT_ASSET_RATIO
# 0        688519               南亚新材  ...    111.438968         65.894938
# 1        688336               三生国健  ...   1468.559883          6.621437
# 2        688366               昊海生科  ...    307.612123         17.640608
# 3        688199               久日新材  ...    269.541881         31.233680
# 4        688318               财富趋势  ...    730.408522         12.219895
#
# [5 rows x 8 columns]
# scrapping data in page 2
# scrapping data in page 3
# scrapping data in page 4
# sample year 2010 data
#   SECURITY_CODE SECURITY_NAME_ABBR  ... CURRENT_RATIO  DEBT_ASSET_RATIO
# 0        688519               南亚新材  ...    111.438968         65.894938
# 1        688336               三生国健  ...   1468.559883          6.621437
# 2        688366               昊海生科  ...    307.612123         17.640608
# 3        688199               久日新材  ...    269.541881         31.233680
# 4        688318               财富趋势  ...    730.408522         12.219895
#
# [5 rows x 8 columns]
# scrapping year 2011 data
# scrapping data in page 1
# sample page 1 data
#   SECURITY_CODE SECURITY_NAME_ABBR  ... CURRENT_RATIO  DEBT_ASSET_RATIO
# 0        688393                安必平  ...    162.841221         56.834154
# 1        688377                迪威尔  ...    109.895814         48.543008
# 2        688196               卓越新能  ...    142.484170         37.965258
# 3        688318               财富趋势  ...    853.732479         10.839610
# 4        688078               龙软科技  ...    245.007507         36.732161
#
# [5 rows x 8 columns]
# scrapping data in page 2
# scrapping data in page 3
# scrapping data in page 4
# sample year 2011 data
#   SECURITY_CODE SECURITY_NAME_ABBR  ... CURRENT_RATIO  DEBT_ASSET_RATIO
# 0        688393                安必平  ...    162.841221         56.834154
# 1        688377                迪威尔  ...    109.895814         48.543008
# 2        688196               卓越新能  ...    142.484170         37.965258
# 3        688318               财富趋势  ...    853.732479         10.839610
# 4        688078               龙软科技  ...    245.007507         36.732161
#
# [5 rows x 8 columns]
# scrapping year 2012 data
# scrapping data in page 1
# sample page 1 data
#   SECURITY_CODE SECURITY_NAME_ABBR  ... CURRENT_RATIO  DEBT_ASSET_RATIO
# 0        688056               莱伯泰科  ...    188.533414         39.704746
# 1        688138               清溢光电  ...    109.581450         48.411009
# 2        688589                力合微  ...    254.964352         36.591785
# 3        688208               道通科技  ...    140.609037         57.674582
# 4        688398               赛特新材  ...    111.729632         44.884020
#
# [5 rows x 8 columns]
# scrapping data in page 2
# scrapping data in page 3
# scrapping data in page 4
# sample year 2012 data
#   SECURITY_CODE SECURITY_NAME_ABBR  ... CURRENT_RATIO  DEBT_ASSET_RATIO
# 0        688056               莱伯泰科  ...    188.533414         39.704746
# 1        688138               清溢光电  ...    109.581450         48.411009
# 2        688589                力合微  ...    254.964352         36.591785
# 3        688208               道通科技  ...    140.609037         57.674582
# 4        688398               赛特新材  ...    111.729632         44.884020
#
# [5 rows x 8 columns]
# scrapping year 2013 data
# scrapping data in page 1
# sample page 1 data
#   SECURITY_CODE SECURITY_NAME_ABBR  ... CURRENT_RATIO  DEBT_ASSET_RATIO
# 0        688981               中芯国际  ...    166.213586         42.671738
# 1        688096               京源环保  ...    128.966764         64.044384
# 2        688300               联瑞新材  ...    129.159067         59.343309
# 3        688508                芯朋微  ...    472.564938         28.100229
# 4        688026               洁特生物  ...     72.465624         34.057943
#
# [5 rows x 8 columns]
# scrapping data in page 2
# sample page 2 data
#   SECURITY_CODE SECURITY_NAME_ABBR  ... CURRENT_RATIO  DEBT_ASSET_RATIO
# 0        688181               八亿时空  ...    293.144366         15.858293
# 1        688360               德马科技  ...     87.327233         92.158283
# 2        688106               金宏气体  ...     86.011710         64.546040
# 3        688579               山大地纬  ...    260.560617         44.411917
# 4        688122               西部超导  ...    118.288565         66.255340
#
# [5 rows x 8 columns]
# scrapping data in page 3
# scrapping data in page 4
# sample year 2013 data
#   SECURITY_CODE SECURITY_NAME_ABBR  ... CURRENT_RATIO  DEBT_ASSET_RATIO
# 0        688981               中芯国际  ...    166.213586         42.671738
# 1        688096               京源环保  ...    128.966764         64.044384
# 2        688300               联瑞新材  ...    129.159067         59.343309
# 3        688508                芯朋微  ...    472.564938         28.100229
# 4        688026               洁特生物  ...     72.465624         34.057943
#
# [5 rows x 8 columns]
# scrapping year 2014 data
# scrapping data in page 1
# sample page 1 data
#   SECURITY_CODE SECURITY_NAME_ABBR  ... CURRENT_RATIO  DEBT_ASSET_RATIO
# 0        688981               中芯国际  ...    199.806736         42.667625
# 1        688390                固德威  ...    113.737961         78.980426
# 2        688096               京源环保  ...    125.257148         70.051191
# 3        688388               嘉元科技  ...     42.543040         50.881302
# 4        688168                安博通  ...    339.508452         28.996545
#
# [5 rows x 8 columns]
# scrapping data in page 2
# sample page 2 data
#   SECURITY_CODE SECURITY_NAME_ABBR  ... CURRENT_RATIO  DEBT_ASSET_RATIO
# 0        688080                映翰通  ...    430.286600         23.126298
# 1        688078               龙软科技  ...    339.123637         27.613837
# 2        688556               高测股份  ...    116.054754         68.515313
# 3        688181               八亿时空  ...    213.350323         31.853401
# 4        688360               德马科技  ...    104.062733         77.216333
#
# [5 rows x 8 columns]
# scrapping data in page 3
# scrapping data in page 4
# sample year 2014 data
#   SECURITY_CODE SECURITY_NAME_ABBR  ... CURRENT_RATIO  DEBT_ASSET_RATIO
# 0        688981               中芯国际  ...    199.806736         42.667625
# 1        688390                固德威  ...    113.737961         78.980426
# 2        688096               京源环保  ...    125.257148         70.051191
# 3        688388               嘉元科技  ...     42.543040         50.881302
# 4        688168                安博通  ...    339.508452         28.996545
#
# [5 rows x 8 columns]
# scrapping year 2015 data
# scrapping data in page 1
# sample page 1 data
#   SECURITY_CODE SECURITY_NAME_ABBR  ... CURRENT_RATIO  DEBT_ASSET_RATIO
# 0        688095               福昕软件  ...    128.798671         45.385295
# 1        688579               山大地纬  ...    197.105385         53.681056
# 2        688556               高测股份  ...    203.486491         36.105915
# 3        688096               京源环保  ...    176.795366         52.503276
# 4        688518               联赢激光  ...    166.618057         59.107919
#
# [5 rows x 8 columns]
# scrapping data in page 2
# sample page 2 data
#   SECURITY_CODE SECURITY_NAME_ABBR  ... CURRENT_RATIO  DEBT_ASSET_RATIO
# 0        688086               紫晶存储  ...    131.946228         56.045965
# 1        688335               复洁环保  ...    136.522701         56.245374
# 2        688299               长阳科技  ...     79.369913         79.445054
# 3        688357               建龙微纳  ...     40.986471         89.353189
# 4        688078               龙软科技  ...    272.433901         32.964770
#
# [5 rows x 8 columns]
# scrapping data in page 3
# scrapping data in page 4
# sample year 2015 data
#   SECURITY_CODE SECURITY_NAME_ABBR  ... CURRENT_RATIO  DEBT_ASSET_RATIO
# 0        688095               福昕软件  ...    128.798671         45.385295
# 1        688579               山大地纬  ...    197.105385         53.681056
# 2        688556               高测股份  ...    203.486491         36.105915
# 3        688096               京源环保  ...    176.795366         52.503276
# 4        688518               联赢激光  ...    166.618057         59.107919
#
# [5 rows x 8 columns]
# scrapping year 2016 data
# scrapping data in page 1
# sample page 1 data
#   SECURITY_CODE SECURITY_NAME_ABBR  ... CURRENT_RATIO  DEBT_ASSET_RATIO
# 0        688566                吉贝尔  ...    341.523956         24.680233
# 1        688599               天合光能  ...    123.585414         75.561154
# 2        688520               神州细胞  ...    110.185810         80.938000
# 3        688312               燕麦科技  ...   1276.554668          7.586574
# 4        688518               联赢激光  ...    155.272058         63.808517
#
# [5 rows x 8 columns]
# scrapping data in page 2
# sample page 2 data
#   SECURITY_CODE SECURITY_NAME_ABBR  ... CURRENT_RATIO  DEBT_ASSET_RATIO
# 0        688318               财富趋势  ...    707.279114         12.927986
# 1        688155               先惠技术  ...    239.107230         42.768423
# 2        688600               皖仪科技  ...    230.976631         48.621136
# 3        688508                芯朋微  ...    404.024244         25.740948
# 4        688311               盟升电子  ...    457.339028         16.680311
#
# [5 rows x 8 columns]
# scrapping data in page 3
# sample page 3 data
#   SECURITY_CODE SECURITY_NAME_ABBR  ... CURRENT_RATIO  DEBT_ASSET_RATIO
# 0        688166               博瑞医药  ...    127.495576         42.699049
# 1        688138               清溢光电  ...    329.665586         14.695194
# 2        688021               奥福环保  ...    111.082561         53.423777
# 3        688363               华熙生物  ...    256.230368         25.147262
# 4        688299               长阳科技  ...     56.013503         81.207615
#
# [5 rows x 8 columns]
# scrapping data in page 4
# sample page 4 data
#   SECURITY_CODE SECURITY_NAME_ABBR  ... CURRENT_RATIO  DEBT_ASSET_RATIO
# 0        688007               光峰科技  ...    124.631272         81.786720
# 1        688005               容百科技  ...    112.610076         69.919131
# 2        688008               澜起科技  ...    489.699611         21.253080
# 3        688006               杭可科技  ...    147.282934         61.189887
# 4        688003               天准科技  ...    362.959575         20.281997
#
# [5 rows x 8 columns]
# sample year 2016 data
#   SECURITY_CODE SECURITY_NAME_ABBR  ... CURRENT_RATIO  DEBT_ASSET_RATIO
# 0        688566                吉贝尔  ...    341.523956         24.680233
# 1        688599               天合光能  ...    123.585414         75.561154
# 2        688520               神州细胞  ...    110.185810         80.938000
# 3        688312               燕麦科技  ...   1276.554668          7.586574
# 4        688518               联赢激光  ...    155.272058         63.808517
#
# [5 rows x 8 columns]
# scrapping year 2017 data
# scrapping data in page 1
# sample page 1 data
#   SECURITY_CODE SECURITY_NAME_ABBR  ... CURRENT_RATIO  DEBT_ASSET_RATIO
# 0        688577               浙海德曼  ...    117.151650         58.820559
# 1        688056               莱伯泰科  ...    240.050617         35.785722
# 2        688550               瑞联新材  ...    133.341039         48.102730
# 3        688513               苑东生物  ...    313.092219         24.781131
# 4        688017               绿的谐波  ...    413.218898         19.111289
#
# [5 rows x 8 columns]
# scrapping data in page 2
# sample page 2 data
#   SECURITY_CODE SECURITY_NAME_ABBR  ... CURRENT_RATIO  DEBT_ASSET_RATIO
# 0        688600               皖仪科技  ...    199.020589         42.814314
# 1        688579               山大地纬  ...    367.673422         24.640664
# 2        688567               孚能科技  ...    101.921867         81.149308
# 3        688528               秦川物联  ...    156.592269         36.272467
# 4        688180               君实生物  ...    880.004159          8.229392
#
# [5 rows x 8 columns]
# scrapping data in page 3
# sample page 3 data
#   SECURITY_CODE SECURITY_NAME_ABBR  ... CURRENT_RATIO  DEBT_ASSET_RATIO
# 0        688178                万德斯  ...    216.318226         40.224900
# 1        688181               八亿时空  ...    208.366276         28.438732
# 2        688081               兴图新科  ...    243.899728         39.173378
# 3        688078               龙软科技  ...    282.283110         33.038084
# 4        688268               华特气体  ...    221.414271         29.167562
#
# [5 rows x 8 columns]
# scrapping data in page 4
# sample page 4 data
#   SECURITY_CODE SECURITY_NAME_ABBR  ... CURRENT_RATIO  DEBT_ASSET_RATIO
# 0        688033               天宜上佳  ...   1092.014249          7.067444
# 1        688028                沃尔德  ...    466.641013         10.731091
# 2        688022               瀚川智能  ...    130.532003         62.852296
# 3        688020               方邦股份  ...   1426.627836          5.568665
# 4        688015               交控科技  ...    128.814047         76.856618
#
# [5 rows x 8 columns]
# sample year 2017 data
#   SECURITY_CODE SECURITY_NAME_ABBR  ... CURRENT_RATIO  DEBT_ASSET_RATIO
# 0        688577               浙海德曼  ...    117.151650         58.820559
# 1        688056               莱伯泰科  ...    240.050617         35.785722
# 2        688550               瑞联新材  ...    133.341039         48.102730
# 3        688513               苑东生物  ...    313.092219         24.781131
# 4        688017               绿的谐波  ...    413.218898         19.111289
#
# [5 rows x 8 columns]
# scrapping year 2018 data
# scrapping data in page 1
# sample page 1 data
#   SECURITY_CODE SECURITY_NAME_ABBR  ... CURRENT_RATIO  DEBT_ASSET_RATIO
# 0        688577               浙海德曼  ...    148.770053         45.497598
# 1        688056               莱伯泰科  ...    285.273674         30.555915
# 2        688550               瑞联新材  ...    117.432456         54.359310
# 3        688513               苑东生物  ...    274.324324         26.276082
# 4        688017               绿的谐波  ...    881.194572         10.100415
#
# [5 rows x 8 columns]
# scrapping data in page 2
# sample page 2 data
#   SECURITY_CODE SECURITY_NAME_ABBR  ... CURRENT_RATIO  DEBT_ASSET_RATIO
# 0        688277                天智航  ...    581.968520         15.399391
# 1        688600               皖仪科技  ...    207.196798         42.254470
# 2        688579               山大地纬  ...    327.865924         24.981270
# 3        688567               孚能科技  ...    378.850980         25.118043
# 4        688528               秦川物联  ...    139.938558         36.727704
#
# [5 rows x 8 columns]
# scrapping data in page 3
# sample page 3 data
#   SECURITY_CODE SECURITY_NAME_ABBR  ... CURRENT_RATIO  DEBT_ASSET_RATIO
# 0        688099               晶晨股份  ...    248.469665         31.598409
# 1        688088               虹软科技  ...    676.840857         15.564137
# 2        688081               兴图新科  ...    337.553021         28.175019
# 3        688058                宝兰德  ...    756.214640         12.077485
# 4        688036               传音控股  ...    156.477674         62.117824
#
# [5 rows x 8 columns]
# scrapping data in page 4
# sample page 4 data
#   SECURITY_CODE SECURITY_NAME_ABBR  ... CURRENT_RATIO  DEBT_ASSET_RATIO
# 0        688166               博瑞医药  ...    533.354607         12.055174
# 1        688101                三达膜  ...    138.516091         39.571042
# 2        688015               交控科技  ...    121.597267         80.712604
# 3        688222               成都先导  ...    350.658987         23.904312
# 4        688002               睿创微纳  ...    687.313587         15.552859
#
# [5 rows x 8 columns]
# sample year 2018 data
#   SECURITY_CODE SECURITY_NAME_ABBR  ... CURRENT_RATIO  DEBT_ASSET_RATIO
# 0        688577               浙海德曼  ...    148.770053         45.497598
# 1        688056               莱伯泰科  ...    285.273674         30.555915
# 2        688550               瑞联新材  ...    117.432456         54.359310
# 3        688513               苑东生物  ...    274.324324         26.276082
# 4        688017               绿的谐波  ...    881.194572         10.100415
#
# [5 rows x 8 columns]
# scrapping year 2019 data
# scrapping data in page 1
# sample page 1 data
#   SECURITY_CODE SECURITY_NAME_ABBR  ... CURRENT_RATIO  DEBT_ASSET_RATIO
# 0        688599               天合光能  ...    114.480880         65.001743
# 1        688577               浙海德曼  ...    157.225896         42.136083
# 2        688566                吉贝尔  ...    561.484295         21.013085
# 3        688555               泽达易盛  ...    553.181436         17.899095
# 4        688369               致远互联  ...    361.154742         26.977277
#
# [5 rows x 8 columns]
# scrapping data in page 2
# sample page 2 data
#   SECURITY_CODE SECURITY_NAME_ABBR  ... CURRENT_RATIO  DEBT_ASSET_RATIO
# 0        688022               瀚川智能  ...    375.778388         23.424394
# 1        688003               天准科技  ...    673.344920         13.887096
# 2        688399               硕世生物  ...    944.954037         11.571149
# 3        688365               光云科技  ...    744.087598         12.949465
# 4        688222               成都先导  ...    668.157747         19.450760
#
# [5 rows x 8 columns]
# scrapping data in page 3
# sample page 3 data
#   SECURITY_CODE SECURITY_NAME_ABBR  ... CURRENT_RATIO  DEBT_ASSET_RATIO
# 0        688008               澜起科技  ...   2745.226547          5.796728
# 1        688596               正帆科技  ...    138.782203         60.548827
# 2        688378                奥来德  ...    176.737174         45.314900
# 3        688335               复洁环保  ...    231.012435         40.476936
# 4        688188               柏楚电子  ...   3787.545453          3.172267
#
# [5 rows x 8 columns]
# scrapping data in page 4
# sample page 4 data
#   SECURITY_CODE SECURITY_NAME_ABBR  ... CURRENT_RATIO  DEBT_ASSET_RATIO
# 0        688518               联赢激光  ...    208.855381         45.146084
# 1        688520               神州细胞  ...    113.699908         95.693581
# 2        688360               德马科技  ...    169.456581         51.044737
# 3        688366               昊海生科  ...   1096.041961          8.103502
# 4        688268               华特气体  ...    518.607221         15.844455
#
# [5 rows x 8 columns]
# sample year 2019 data
#   SECURITY_CODE SECURITY_NAME_ABBR  ... CURRENT_RATIO  DEBT_ASSET_RATIO
# 0        688599               天合光能  ...    114.480880         65.001743
# 1        688577               浙海德曼  ...    157.225896         42.136083
# 2        688566                吉贝尔  ...    561.484295         21.013085
# 3        688555               泽达易盛  ...    553.181436         17.899095
# 4        688369               致远互联  ...    361.154742         26.977277
#
# [5 rows x 8 columns]
# sample 2010-2019 data
#   SECURITY_CODE SECURITY_NAME_ABBR  ... DEBT_ASSET_RATIO  year
# 0        688519               南亚新材  ...        65.894938  2010
# 1        688336               三生国健  ...         6.621437  2010
# 2        688366               昊海生科  ...        17.640608  2010
# 3        688199               久日新材  ...        31.233680  2010
# 4        688318               财富趋势  ...        12.219895  2010
#
# [5 rows x 9 columns]
# scrapping income statement data
# scrapping year 2010 data
# scrapping data in page 1
# sample page 1 data
#   SECURITY_CODE  PARENT_NETPROFIT  TOTAL_OPERATE_INCOME  OPERATE_PROFIT_RATIO
# 0        688366      5.525172e+07          1.463647e+08             65.868476
# 1        688199      1.635962e+07          1.212591e+08                   NaN
# 2        688318      6.142088e+07          7.634359e+07             39.491513
# 3        688122      7.747011e+07          4.148383e+08             21.766270
# 4        688336      1.565115e+08          3.429396e+08             64.738145
# scrapping data in page 2
# scrapping data in page 3
# scrapping data in page 4
# sample year 2010 data
#   SECURITY_CODE  PARENT_NETPROFIT  TOTAL_OPERATE_INCOME  OPERATE_PROFIT_RATIO
# 0        688366      5.525172e+07          1.463647e+08             65.868476
# 1        688199      1.635962e+07          1.212591e+08                   NaN
# 2        688318      6.142088e+07          7.634359e+07             39.491513
# 3        688122      7.747011e+07          4.148383e+08             21.766270
# 4        688336      1.565115e+08          3.429396e+08             64.738145
# scrapping year 2011 data
# scrapping data in page 1
# sample page 1 data
#   SECURITY_CODE  PARENT_NETPROFIT  TOTAL_OPERATE_INCOME  OPERATE_PROFIT_RATIO
# 0        688393       27150000.00          8.771890e+07                   NaN
# 1        688377       40286198.22          3.540725e+08                   NaN
# 2        688196       63969968.86          5.429296e+08                   NaN
# 3        688318       70759200.00          8.943000e+07              14.90945
# 4        688078       18671265.09          7.941286e+07                   NaN
# scrapping data in page 2
# scrapping data in page 3
# scrapping data in page 4
# sample year 2011 data
#   SECURITY_CODE  PARENT_NETPROFIT  TOTAL_OPERATE_INCOME  OPERATE_PROFIT_RATIO
# 0        688393       27150000.00          8.771890e+07                   NaN
# 1        688377       40286198.22          3.540725e+08                   NaN
# 2        688196       63969968.86          5.429296e+08                   NaN
# 3        688318       70759200.00          8.943000e+07              14.90945
# 4        688078       18671265.09          7.941286e+07                   NaN
# scrapping year 2012 data
# scrapping data in page 1
# sample page 1 data
#   SECURITY_CODE  PARENT_NETPROFIT  TOTAL_OPERATE_INCOME  OPERATE_PROFIT_RATIO
# 0        688056       25026651.41          1.888648e+08                   NaN
# 1        688138       22219764.47          2.585467e+08                   NaN
# 2        688589       19174100.00          9.659440e+07                   NaN
# 3        688208       56876100.00          1.768212e+08                   NaN
# 4        688398       22396080.73          1.341335e+08                   NaN
# scrapping data in page 2
# scrapping data in page 3
# scrapping data in page 4
# sample year 2012 data
#   SECURITY_CODE  PARENT_NETPROFIT  TOTAL_OPERATE_INCOME  OPERATE_PROFIT_RATIO
# 0        688056       25026651.41          1.888648e+08                   NaN
# 1        688138       22219764.47          2.585467e+08                   NaN
# 2        688589       19174100.00          9.659440e+07                   NaN
# 3        688208       56876100.00          1.768212e+08                   NaN
# 4        688398       22396080.73          1.341335e+08                   NaN
# scrapping year 2013 data
# scrapping data in page 1
# sample page 1 data
#   SECURITY_CODE  PARENT_NETPROFIT  TOTAL_OPERATE_INCOME  OPERATE_PROFIT_RATIO
# 0        688981      1.731770e+08          2.068964e+09                   NaN
# 1        688096      8.935881e+05          2.531208e+07            121.351425
# 2        688300      1.423983e+07          1.204986e+08              8.538937
# 3        688026      1.355593e+07          7.002347e+07                   NaN
# 4        688229      5.390883e+06          2.337531e+07                   NaN
# scrapping data in page 2
# sample page 2 data
#   SECURITY_CODE  PARENT_NETPROFIT  TOTAL_OPERATE_INCOME  OPERATE_PROFIT_RATIO
# 0        688360        8917453.03          3.191893e+08            343.763629
# 1        688508       18449178.43          1.582997e+08            138.094710
# 2        688106       61340968.76          4.425125e+08             65.576130
# 3        688579       30493629.03          2.019354e+08            125.691066
# 4        688122       61238143.99          6.654624e+08            -41.892001
# scrapping data in page 3
# scrapping data in page 4
# sample year 2013 data
#   SECURITY_CODE  PARENT_NETPROFIT  TOTAL_OPERATE_INCOME  OPERATE_PROFIT_RATIO
# 0        688981      1.731770e+08          2.068964e+09                   NaN
# 1        688096      8.935881e+05          2.531208e+07            121.351425
# 2        688300      1.423983e+07          1.204986e+08              8.538937
# 3        688026      1.355593e+07          7.002347e+07                   NaN
# 4        688229      5.390883e+06          2.337531e+07                   NaN
# scrapping year 2014 data
# scrapping data in page 1
# sample page 1 data
#   SECURITY_CODE  PARENT_NETPROFIT  TOTAL_OPERATE_INCOME  OPERATE_PROFIT_RATIO
# 0        688981      1.529690e+08          1.969966e+09            -30.382656
# 1        688390      2.058671e+06          1.035614e+08            115.694544
# 2        688096      1.559671e+06          3.955567e+07            372.001589
# 3        688388      1.079887e+07          3.162641e+08            169.797526
# 4        688168      4.416858e+06          4.712073e+07                   NaN
# scrapping data in page 2
# sample page 2 data
#   SECURITY_CODE  PARENT_NETPROFIT  TOTAL_OPERATE_INCOME  OPERATE_PROFIT_RATIO
# 0        688080        4339160.00          6.503509e+07           -135.084861
# 1        688078        8714667.70          7.310235e+07            -86.748519
# 2        688556        8264618.01          6.885262e+07           4520.511934
# 3        688181        8714586.22          6.076381e+07            -31.070250
# 4        688360       13482615.75          3.601040e+08            132.539313
# scrapping data in page 3
# scrapping data in page 4
# sample year 2014 data
#   SECURITY_CODE  PARENT_NETPROFIT  TOTAL_OPERATE_INCOME  OPERATE_PROFIT_RATIO
# 0        688981      1.529690e+08          1.969966e+09            -30.382656
# 1        688390      2.058671e+06          1.035614e+08            115.694544
# 2        688096      1.559671e+06          3.955567e+07            372.001589
# 3        688388      1.079887e+07          3.162641e+08            169.797526
# 4        688168      4.416858e+06          4.712073e+07                   NaN
# scrapping year 2015 data
# scrapping data in page 1
# sample page 1 data
#   SECURITY_CODE  PARENT_NETPROFIT  TOTAL_OPERATE_INCOME  OPERATE_PROFIT_RATIO
# 0        688095       38686533.06          1.409257e+08            -18.960960
# 1        688579       47820088.67          2.938467e+08             46.096420
# 2        688556        1196261.29          6.491357e+07            -67.933083
# 3        688096       11148195.23          5.911164e+07            539.148866
# 4        688518       51655741.39          2.655351e+08            172.629622
# scrapping data in page 2
# sample page 2 data
#   SECURITY_CODE  PARENT_NETPROFIT  TOTAL_OPERATE_INCOME  OPERATE_PROFIT_RATIO
# 0        688309        3685871.25          1.321067e+07            -70.735999
# 1        688215        5962447.78          5.174440e+07            731.976567
# 2        688086       36644698.67          1.276574e+08            572.339630
# 3        688335        2401979.38          4.465407e+07            189.502451
# 4        688299        3871603.08          2.498609e+08            102.455662
# scrapping data in page 3
# scrapping data in page 4
# sample year 2015 data
#   SECURITY_CODE  PARENT_NETPROFIT  TOTAL_OPERATE_INCOME  OPERATE_PROFIT_RATIO
# 0        688095       38686533.06          1.409257e+08            -18.960960
# 1        688579       47820088.67          2.938467e+08             46.096420
# 2        688556        1196261.29          6.491357e+07            -67.933083
# 3        688096       11148195.23          5.911164e+07            539.148866
# 4        688518       51655741.39          2.655351e+08            172.629622
# scrapping year 2016 data
# scrapping data in page 1
# sample page 1 data
#   SECURITY_CODE  PARENT_NETPROFIT  TOTAL_OPERATE_INCOME  OPERATE_PROFIT_RATIO
# 0        688566      7.693968e+07          4.444235e+08                   NaN
# 1        688599      4.791068e+08          2.259389e+10                   NaN
# 2        688520     -1.214295e+07          9.812582e+07                   NaN
# 3        688312      9.234015e+07          2.235183e+08                   NaN
# 4        688518      6.855316e+07          4.162033e+08             30.408452
# scrapping data in page 2
# sample page 2 data
#   SECURITY_CODE  PARENT_NETPROFIT  TOTAL_OPERATE_INCOME  OPERATE_PROFIT_RATIO
# 0        688318      1.387106e+08          1.794455e+08             13.733751
# 1        688155      2.663153e+07          1.782199e+08                   NaN
# 2        688600      3.058987e+07          1.947649e+08                   NaN
# 3        688508      3.005125e+07          2.295342e+08             98.445875
# 4        688311      1.591479e+07          1.458416e+08                   NaN
# scrapping data in page 3
# sample page 3 data
#   SECURITY_CODE  PARENT_NETPROFIT  TOTAL_OPERATE_INCOME  OPERATE_PROFIT_RATIO
# 0        688166      1.706097e+07          2.009248e+08                   NaN
# 1        688138      4.573595e+07          3.146632e+08            -28.842238
# 2        688021      6.124718e+06          9.286866e+07                   NaN
# 3        688363      2.694290e+08          7.331226e+08                   NaN
# 4        688299      2.674397e+07          3.803774e+08           1449.347874
# scrapping data in page 4
# sample page 4 data
#   SECURITY_CODE  PARENT_NETPROFIT  TOTAL_OPERATE_INCOME  OPERATE_PROFIT_RATIO
# 0        688007       13943617.40          3.549547e+08                   NaN
# 1        688005        6877015.78          8.851923e+08                   NaN
# 2        688008       92804284.98          8.449446e+08                   NaN
# 3        688006       89706630.71          4.102153e+08             42.773315
# 4        688003       31489793.47          1.808496e+08             -9.455311
# sample year 2016 data
#   SECURITY_CODE  PARENT_NETPROFIT  TOTAL_OPERATE_INCOME  OPERATE_PROFIT_RATIO
# 0        688566      7.693968e+07          4.444235e+08                   NaN
# 1        688599      4.791068e+08          2.259389e+10                   NaN
# 2        688520     -1.214295e+07          9.812582e+07                   NaN
# 3        688312      9.234015e+07          2.235183e+08                   NaN
# 4        688518      6.855316e+07          4.162033e+08             30.408452
# scrapping year 2017 data
# scrapping data in page 1
# sample page 1 data
#   SECURITY_CODE  PARENT_NETPROFIT  TOTAL_OPERATE_INCOME  OPERATE_PROFIT_RATIO
# 0        688577       36628562.52          3.331508e+08            415.416303
# 1        688056       49071041.52          3.220819e+08             25.010054
# 2        688550       78008660.92          7.191041e+08             40.865369
# 3        688513       64365623.71          4.763380e+08             88.416818
# 4        688017       48586338.44          1.757021e+08                   NaN
# scrapping data in page 2
# sample page 2 data
#   SECURITY_CODE  PARENT_NETPROFIT  TOTAL_OPERATE_INCOME  OPERATE_PROFIT_RATIO
# 0        688277       21669460.85          7.329475e+07            138.345296
# 1        688600       49244696.36          2.837548e+08            450.623056
# 2        688579       61735954.01          3.169059e+08             91.970777
# 3        688567       18261332.45          1.338614e+09           2710.638608
# 4        688528        9799252.08          1.611262e+08            -53.527026
# scrapping data in page 3
# sample page 3 data
#   SECURITY_CODE  PARENT_NETPROFIT  TOTAL_OPERATE_INCOME  OPERATE_PROFIT_RATIO
# 0        688100      1.487450e+08          9.950934e+08            120.256271
# 1        688178      6.975418e+07          2.825464e+08            398.091562
# 2        688181      5.334392e+07          2.307539e+08            284.447726
# 3        688081      3.115335e+07          1.488448e+08           1536.319395
# 4        688078      2.160189e+07          1.072690e+08            691.904787
# scrapping data in page 4
# sample page 4 data
#   SECURITY_CODE  PARENT_NETPROFIT  TOTAL_OPERATE_INCOME  OPERATE_PROFIT_RATIO
# 0        688066      4.759613e+07          2.963474e+08             50.284345
# 1        688033      2.219309e+08          5.071340e+08             13.520881
# 2        688028      5.814118e+07          2.334644e+08             49.258761
# 3        688022      3.219676e+07          2.438491e+08            701.796539
# 4        688020      9.629105e+07          2.262545e+08             22.218141
# sample year 2017 data
#   SECURITY_CODE  PARENT_NETPROFIT  TOTAL_OPERATE_INCOME  OPERATE_PROFIT_RATIO
# 0        688577       36628562.52          3.331508e+08            415.416303
# 1        688056       49071041.52          3.220819e+08             25.010054
# 2        688550       78008660.92          7.191041e+08             40.865369
# 3        688513       64365623.71          4.763380e+08             88.416818
# 4        688017       48586338.44          1.757021e+08                   NaN
# scrapping year 2018 data
# scrapping data in page 1
# sample page 1 data
#   SECURITY_CODE  PARENT_NETPROFIT  TOTAL_OPERATE_INCOME  OPERATE_PROFIT_RATIO
# 0        688577      5.766265e+07          4.273634e+08             56.138655
# 1        688056      5.981613e+07          3.500552e+08              2.072280
# 2        688550      9.464213e+07          8.565672e+08             18.710896
# 3        688513      1.350201e+08          7.687586e+08            100.808079
# 4        688017      6.506691e+07          2.195340e+08             28.067111
# scrapping data in page 2
# sample page 2 data
#   SECURITY_CODE  PARENT_NETPROFIT  TOTAL_OPERATE_INCOME  OPERATE_PROFIT_RATIO
# 0        688277        -855977.97          1.267220e+08           -163.966070
# 1        688600       52036636.12          3.264673e+08             -4.068023
# 2        688579       82253499.60          4.061744e+08             31.074281
# 3        688567      -78214828.30          2.275652e+09           -665.947090
# 4        688528       44369396.55          2.026915e+08            246.999364
# scrapping data in page 3
# sample page 3 data
#   SECURITY_CODE  PARENT_NETPROFIT  TOTAL_OPERATE_INCOME  OPERATE_PROFIT_RATIO
# 0        688099      2.825309e+08          2.369069e+09            189.926851
# 1        688088      1.575518e+08          4.580713e+08            140.722478
# 2        688081      4.221376e+07          1.981364e+08             35.811168
# 3        688058      5.144752e+07          1.223700e+08             52.733428
# 4        688036      6.573780e+08          2.264588e+10              6.047248
# scrapping data in page 4
# sample page 4 data
#   SECURITY_CODE  PARENT_NETPROFIT  TOTAL_OPERATE_INCOME  OPERATE_PROFIT_RATIO
# 0        688166      7.320204e+07          4.075033e+08             66.371935
# 1        688101      1.813217e+08          5.899088e+08             -0.881621
# 2        688015      6.639520e+07          1.162520e+09             44.218660
# 3        688222      4.496049e+07          1.511960e+08            267.763022
# 4        688002      1.251681e+08          3.841047e+08            107.917430
# sample year 2018 data
#   SECURITY_CODE  PARENT_NETPROFIT  TOTAL_OPERATE_INCOME  OPERATE_PROFIT_RATIO
# 0        688577      5.766265e+07          4.273634e+08             56.138655
# 1        688056      5.981613e+07          3.500552e+08              2.072280
# 2        688550      9.464213e+07          8.565672e+08             18.710896
# 3        688513      1.350201e+08          7.687586e+08            100.808079
# 4        688017      6.506691e+07          2.195340e+08             28.067111
# scrapping year 2019 data
# scrapping data in page 1
# sample page 1 data
#   SECURITY_CODE  PARENT_NETPROFIT  TOTAL_OPERATE_INCOME  OPERATE_PROFIT_RATIO
# 0        688577      4.559823e+07          3.847362e+08            -21.336483
# 1        688056      6.132360e+07          3.805185e+08             14.922894
# 2        688550      1.484645e+08          9.902292e+08             61.029928
# 3        688513      1.086116e+08          9.472352e+08            -23.068466
# 4        688017      5.847833e+07          1.859010e+08            -14.031144
# scrapping data in page 2
# sample page 2 data
#   SECURITY_CODE  PARENT_NETPROFIT  TOTAL_OPERATE_INCOME  OPERATE_PROFIT_RATIO
# 0        688277     -3.095783e+07          2.295642e+08           -387.804747
# 1        688600      6.650489e+07          4.090340e+08             23.769839
# 2        688579      7.817663e+07          4.885705e+08             -5.444419
# 3        688567      1.312277e+08          2.449629e+09            226.483337
# 4        688528      4.422946e+07          2.449405e+08             -3.441565
# scrapping data in page 3
# sample page 3 data
#   SECURITY_CODE  PARENT_NETPROFIT  TOTAL_OPERATE_INCOME  OPERATE_PROFIT_RATIO
# 0        688099      1.580418e+08          2.357733e+09            -43.157154
# 1        688088      2.103666e+08          5.644770e+08              8.243449
# 2        688081      5.188832e+07          2.003716e+08             19.603585
# 3        688058      6.124312e+07          1.433023e+08             17.063940
# 4        688036      1.793303e+09          2.534593e+10            156.045434
# scrapping data in page 4
# sample page 4 data
#   SECURITY_CODE  PARENT_NETPROFIT  TOTAL_OPERATE_INCOME  OPERATE_PROFIT_RATIO
# 0        688166      1.110833e+08          5.031567e+08             48.248804
# 1        688101      2.766679e+08          7.420087e+08             47.697377
# 2        688015      1.272915e+08          1.651775e+09             84.293264
# 3        688222      1.202661e+08          2.641969e+08            171.986538
# 4        688002      2.020659e+08          6.846563e+08             61.244744
# sample year 2019 data
#   SECURITY_CODE  PARENT_NETPROFIT  TOTAL_OPERATE_INCOME  OPERATE_PROFIT_RATIO
# 0        688577      4.559823e+07          3.847362e+08            -21.336483
# 1        688056      6.132360e+07          3.805185e+08             14.922894
# 2        688550      1.484645e+08          9.902292e+08             61.029928
# 3        688513      1.086116e+08          9.472352e+08            -23.068466
# 4        688017      5.847833e+07          1.859010e+08            -14.031144
# sample 2010-2019 data
#   SECURITY_CODE  PARENT_NETPROFIT  ...  OPERATE_PROFIT_RATIO  year
# 0        688366      5.525172e+07  ...             65.868476  2010
# 1        688199      1.635962e+07  ...                   NaN  2010
# 2        688318      6.142088e+07  ...             39.491513  2010
# 3        688122      7.747011e+07  ...             21.766270  2010
# 4        688336      1.565115e+08  ...             64.738145  2010
#
# [5 rows x 5 columns]
# scrapping achievement report data
# scrapping year 2010 data
# scrapping data in page 1
# sample page 1 data
#   SECURITY_CODE  WEIGHTAVG_ROE      XSMLL
# 0        688366          33.09  80.779166
# 1        688199          37.27  24.843563
# 2        688318          47.40  93.188068
# 3        688122            NaN  35.755438
# 4        688336            NaN  91.647343
# scrapping data in page 2
# scrapping data in page 3
# scrapping data in page 4
# sample year 2010 data
#   SECURITY_CODE  WEIGHTAVG_ROE      XSMLL
# 0        688366          33.09  80.779166
# 1        688199          37.27  24.843563
# 2        688318          47.40  93.188068
# 3        688122            NaN  35.755438
# 4        688336            NaN  91.647343
# scrapping year 2011 data
# scrapping data in page 1
# sample page 1 data
#   SECURITY_CODE  WEIGHTAVG_ROE      XSMLL
# 0        688393          78.67  64.927057
# 1        688377          16.06  29.460432
# 2        688196          29.43   7.218870
# 3        688318          33.67  91.949010
# 4        688078          37.17  55.740809
# scrapping data in page 2
# scrapping data in page 3
# scrapping data in page 4
# sample year 2011 data
#   SECURITY_CODE  WEIGHTAVG_ROE      XSMLL
# 0        688393          78.67  64.927057
# 1        688377          16.06  29.460432
# 2        688196          29.43   7.218870
# 3        688318          33.67  91.949010
# 4        688078          37.17  55.740809
# scrapping year 2012 data
# scrapping data in page 1
# sample page 1 data
#   SECURITY_CODE  WEIGHTAVG_ROE      XSMLL
# 0        688056          25.50  48.460884
# 1        688138           9.92  28.982381
# 2        688589          21.96  53.745869
# 3        688208          74.20  66.832371
# 4        688398          17.95  37.701312
# scrapping data in page 2
# scrapping data in page 3
# scrapping data in page 4
# sample year 2012 data
#   SECURITY_CODE  WEIGHTAVG_ROE      XSMLL
# 0        688056          25.50  48.460884
# 1        688138           9.92  28.982381
# 2        688589          21.96  53.745869
# 3        688208          74.20  66.832371
# 4        688398          17.95  37.701312
# scrapping year 2013 data
# scrapping data in page 1
# sample page 1 data
#   SECURITY_CODE  WEIGHTAVG_ROE      XSMLL
# 0        688981            NaN  21.191089
# 1        688096           7.91  28.486086
# 2        688300          13.76  38.874291
# 3        688026          18.01  46.384921
# 4        688229         133.32  80.520373
# scrapping data in page 2
# sample page 2 data
#   SECURITY_CODE  WEIGHTAVG_ROE      XSMLL
# 0        688360          53.03  25.927049
# 1        688508          23.65  33.663982
# 2        688106          27.75  44.011025
# 3        688579          45.50  45.164364
# 4        688122          10.30  29.348296
# scrapping data in page 3
# scrapping data in page 4
# sample year 2013 data
#   SECURITY_CODE  WEIGHTAVG_ROE      XSMLL
# 0        688981            NaN  21.191089
# 1        688096           7.91  28.486086
# 2        688300          13.76  38.874291
# 3        688026          18.01  46.384921
# 4        688229         133.32  80.520373
# scrapping year 2014 data
# scrapping data in page 1
# sample page 1 data
#   SECURITY_CODE  WEIGHTAVG_ROE      XSMLL
# 0        688981            NaN  24.541134
# 1        688390          14.58  40.399814
# 2        688096          13.40  29.809683
# 3        688388           6.91  13.101014
# 4        688168          39.03  75.802791
# scrapping data in page 2
# sample page 2 data
#   SECURITY_CODE  WEIGHTAVG_ROE      XSMLL
# 0        688080          10.81  51.598847
# 1        688078           6.45  48.856295
# 2        688556          31.96  39.321511
# 3        688181           7.00  42.872388
# 4        688360          36.38  26.732819
# scrapping data in page 3
# scrapping data in page 4
# sample year 2014 data
#   SECURITY_CODE  WEIGHTAVG_ROE      XSMLL
# 0        688981            NaN  24.541134
# 1        688390          14.58  40.399814
# 2        688096          13.40  29.809683
# 3        688388           6.91  13.101014
# 4        688168          39.03  75.802791
# scrapping year 2015 data
# scrapping data in page 1
# sample page 1 data
#   SECURITY_CODE  WEIGHTAVG_ROE      XSMLL
# 0        688095          37.70  89.266446
# 1        688579          35.17  38.142263
# 2        688556           2.94  45.478063
# 3        688096          45.62  40.061060
# 4        688518          30.99  51.141275
# scrapping data in page 2
# sample page 2 data
#   SECURITY_CODE  WEIGHTAVG_ROE      XSMLL
# 0        688309          11.01  96.925113
# 1        688215          36.42  39.107445
# 2        688086          44.16  45.144265
# 3        688335          27.46  37.489424
# 4        688299           3.00  26.059410
# scrapping data in page 3
# scrapping data in page 4
# sample year 2015 data
#   SECURITY_CODE  WEIGHTAVG_ROE      XSMLL
# 0        688095          37.70  89.266446
# 1        688579          35.17  38.142263
# 2        688556           2.94  45.478063
# 3        688096          45.62  40.061060
# 4        688518          30.99  51.141275
# scrapping year 2016 data
# scrapping data in page 1
# sample page 1 data
#   SECURITY_CODE  WEIGHTAVG_ROE      XSMLL
# 0        688566          24.18  84.560351
# 1        688599           6.01  19.063325
# 2        688520         -12.00  77.286474
# 3        688312          47.90  66.345764
# 4        688518          24.73  48.338684
# scrapping data in page 2
# sample page 2 data
#   SECURITY_CODE  WEIGHTAVG_ROE      XSMLL
# 0        688318          24.16  88.831707
# 1        688155          45.12  36.787918
# 2        688600          20.43  55.163304
# 3        688508          16.82  34.678528
# 4        688311           7.69  57.631116
# scrapping data in page 3
# sample page 3 data
#   SECURITY_CODE  WEIGHTAVG_ROE      XSMLL
# 0        688166           8.06  57.674538
# 1        688138          11.25  33.455007
# 2        688021           4.10  46.318848
# 3        688363          24.14  77.360861
# 4        688299          15.16  26.990067
# scrapping data in page 4
# sample page 4 data
#   SECURITY_CODE  WEIGHTAVG_ROE      XSMLL
# 0        688007          35.24  32.973316
# 1        688005           3.17  12.099515
# 2        688008          11.35  51.202823
# 3        688006          56.37  45.162881
# 4        688003          16.63  58.005823
# sample year 2016 data
#   SECURITY_CODE  WEIGHTAVG_ROE      XSMLL
# 0        688566          24.18  84.560351
# 1        688599           6.01  19.063325
# 2        688520         -12.00  77.286474
# 3        688312          47.90  66.345764
# 4        688518          24.73  48.338684
# scrapping year 2017 data
# scrapping data in page 1
# sample page 1 data
#   SECURITY_CODE  WEIGHTAVG_ROE      XSMLL
# 0        688577          21.53  36.470200
# 1        688056          19.17  51.979943
# 2        688550          16.65  37.541212
# 3        688513          15.78  85.044636
# 4        688017          17.76  47.083813
# scrapping data in page 2
# sample page 2 data
#   SECURITY_CODE  WEIGHTAVG_ROE      XSMLL
# 0        688277          14.77  67.209677
# 1        688600          28.10  51.238804
# 2        688579          12.76  47.161493
# 3        688567           5.59  16.482912
# 4        688528           6.69  47.815444
# scrapping data in page 3
# sample page 3 data
#   SECURITY_CODE  WEIGHTAVG_ROE      XSMLL
# 0        688100          14.05  35.605502
# 1        688178          57.41  37.584969
# 2        688181          20.49  50.888460
# 3        688081          26.50  66.227771
# 4        688078          17.59  54.199101
# scrapping data in page 4
# sample page 4 data
#   SECURITY_CODE  WEIGHTAVG_ROE      XSMLL
# 0        688066          13.44  59.628323
# 1        688033          22.55  73.122904
# 2        688028          21.04  51.838416
# 3        688022          44.09  37.196049
# 4        688020          32.20  73.173459
# sample year 2017 data
#   SECURITY_CODE  WEIGHTAVG_ROE      XSMLL
# 0        688577          21.53  36.470200
# 1        688056          19.17  51.979943
# 2        688550          16.65  37.541212
# 3        688513          15.78  85.044636
# 4        688017          17.76  47.083813
# scrapping year 2018 data
# scrapping data in page 1
# sample page 1 data
#   SECURITY_CODE  WEIGHTAVG_ROE      XSMLL
# 0        688577          23.77  35.805602
# 1        688056          22.84  48.428385
# 2        688550          17.80  35.039581
# 3        688513          26.35  88.636560
# 4        688017          20.06  48.826327
# scrapping data in page 2
# sample page 2 data
#   SECURITY_CODE  WEIGHTAVG_ROE      XSMLL
# 0        688277          -0.26  76.121892
# 1        688600          24.17  52.642418
# 2        688579          13.23  47.166138
# 3        688567          -1.47   5.586469
# 4        688528          20.12  44.424600
# scrapping data in page 3
# sample page 3 data
#   SECURITY_CODE  WEIGHTAVG_ROE      XSMLL
# 0        688099          28.98  34.811304
# 1        688088          22.85  94.286275
# 2        688081          24.50  70.751243
# 3        688058          35.13  94.980742
# 4        688036          18.49  24.448213
# scrapping data in page 4
# sample page 4 data
#   SECURITY_CODE  WEIGHTAVG_ROE      XSMLL
# 0        688166          15.16  58.453937
# 1        688101          13.63  41.714154
# 2        688015          17.91  26.926537
# 3        688222          36.41  82.661739
# 4        688002          27.61  60.073723
# sample year 2018 data
#   SECURITY_CODE  WEIGHTAVG_ROE      XSMLL
# 0        688577          23.77  35.805602
# 1        688056          22.84  48.428385
# 2        688550          17.80  35.039581
# 3        688513          26.35  88.636560
# 4        688017          20.06  48.826327
# scrapping year 2019 data
# scrapping data in page 1
# sample page 1 data
#   SECURITY_CODE  WEIGHTAVG_ROE      XSMLL
# 0        688577          14.64  34.205215
# 1        688056          18.79  46.311781
# 2        688550          23.39  39.667272
# 3        688513          17.54  90.253176
# 4        688017           9.70  49.372834
# scrapping data in page 2
# sample page 2 data
#   SECURITY_CODE  WEIGHTAVG_ROE      XSMLL
# 0        688277          -5.39  84.947137
# 1        688600          24.12  53.118399
# 2        688579           9.53  45.363024
# 3        688567           1.88  23.492882
# 4        688528          16.40  43.865177
# scrapping data in page 3
# sample page 3 data
#   SECURITY_CODE  WEIGHTAVG_ROE      XSMLL
# 0        688099           9.24  33.928395
# 1        688088          12.67  93.271311
# 2        688081          23.18  77.422480
# 3        688058          19.32  96.457611
# 4        688036          33.53  27.357223
# scrapping data in page 4
# sample page 4 data
#   SECURITY_CODE  WEIGHTAVG_ROE      XSMLL
# 0        688166          12.96  64.044820
# 1        688101          16.40  41.303326
# 2        688015          18.51  26.656726
# 3        688222          26.68  81.548638
# 4        688002          12.79  50.415288
# sample year 2019 data
#   SECURITY_CODE  WEIGHTAVG_ROE      XSMLL
# 0        688577          14.64  34.205215
# 1        688056          18.79  46.311781
# 2        688550          23.39  39.667272
# 3        688513          17.54  90.253176
# 4        688017           9.70  49.372834
# sample 2010-2019 data
#   SECURITY_CODE  WEIGHTAVG_ROE      XSMLL  year
# 0        688366          33.09  80.779166  2010
# 1        688199          37.27  24.843563  2010
# 2        688318          47.40  93.188068  2010
# 3        688122            NaN  35.755438  2010
# 4        688336            NaN  91.647343  2010
# sample combined statements data
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-115-263240bbee7e> in <module>()
# ----> 1 main()
#
# <ipython-input-107-e64b846699df> in main()
#       1 def main():
#       2   DfData = scrapping_eastmoney_kcb_multiple_statements(range(2010, 2020), range(1, 5))
# ----> 3   calculate_shang(DfData)
#
# <ipython-input-106-105f2827fc4b> in calculate_shang(df_data)
#       4
#       5   df_data_complete = pd.DataFrame()
# ----> 6   year_groups = dict(df_data.groupby("year"))
#       7   for year in year_groups.keys():
#       8     if year > 2010:
#
# TypeError: attribute of type 'str' is not callable

# %%
DfData = scrapping_eastmoney_kcb_multiple_statements(range(2010, 2020), range(1, 5))
# Out:
# scrapping balance sheet data
# scrapping year 2010 data
# scrapping data in page 1
# sample page 1 data
#   SECURITY_CODE SECURITY_NAME_ABBR  ... CURRENT_RATIO  DEBT_ASSET_RATIO
# 0        688519               南亚新材  ...    111.438968         65.894938
# 1        688336               三生国健  ...   1468.559883          6.621437
# 2        688366               昊海生科  ...    307.612123         17.640608
# 3        688199               久日新材  ...    269.541881         31.233680
# 4        688318               财富趋势  ...    730.408522         12.219895
#
# [5 rows x 8 columns]
# scrapping data in page 2
# scrapping data in page 3
# scrapping data in page 4
# sample year 2010 data
#   SECURITY_CODE SECURITY_NAME_ABBR  ... CURRENT_RATIO  DEBT_ASSET_RATIO
# 0        688519               南亚新材  ...    111.438968         65.894938
# 1        688336               三生国健  ...   1468.559883          6.621437
# 2        688366               昊海生科  ...    307.612123         17.640608
# 3        688199               久日新材  ...    269.541881         31.233680
# 4        688318               财富趋势  ...    730.408522         12.219895
#
# [5 rows x 8 columns]
# scrapping year 2011 data
# scrapping data in page 1
# sample page 1 data
#   SECURITY_CODE SECURITY_NAME_ABBR  ... CURRENT_RATIO  DEBT_ASSET_RATIO
# 0        688393                安必平  ...    162.841221         56.834154
# 1        688377                迪威尔  ...    109.895814         48.543008
# 2        688196               卓越新能  ...    142.484170         37.965258
# 3        688318               财富趋势  ...    853.732479         10.839610
# 4        688078               龙软科技  ...    245.007507         36.732161
#
# [5 rows x 8 columns]
# scrapping data in page 2
# scrapping data in page 3
# scrapping data in page 4
# sample year 2011 data
#   SECURITY_CODE SECURITY_NAME_ABBR  ... CURRENT_RATIO  DEBT_ASSET_RATIO
# 0        688393                安必平  ...    162.841221         56.834154
# 1        688377                迪威尔  ...    109.895814         48.543008
# 2        688196               卓越新能  ...    142.484170         37.965258
# 3        688318               财富趋势  ...    853.732479         10.839610
# 4        688078               龙软科技  ...    245.007507         36.732161
#
# [5 rows x 8 columns]
# scrapping year 2012 data
# scrapping data in page 1
# sample page 1 data
#   SECURITY_CODE SECURITY_NAME_ABBR  ... CURRENT_RATIO  DEBT_ASSET_RATIO
# 0        688056               莱伯泰科  ...    188.533414         39.704746
# 1        688138               清溢光电  ...    109.581450         48.411009
# 2        688589                力合微  ...    254.964352         36.591785
# 3        688208               道通科技  ...    140.609037         57.674582
# 4        688398               赛特新材  ...    111.729632         44.884020
#
# [5 rows x 8 columns]
# scrapping data in page 2
# scrapping data in page 3
# scrapping data in page 4
# sample year 2012 data
#   SECURITY_CODE SECURITY_NAME_ABBR  ... CURRENT_RATIO  DEBT_ASSET_RATIO
# 0        688056               莱伯泰科  ...    188.533414         39.704746
# 1        688138               清溢光电  ...    109.581450         48.411009
# 2        688589                力合微  ...    254.964352         36.591785
# 3        688208               道通科技  ...    140.609037         57.674582
# 4        688398               赛特新材  ...    111.729632         44.884020
#
# [5 rows x 8 columns]
# scrapping year 2013 data
# scrapping data in page 1
# sample page 1 data
#   SECURITY_CODE SECURITY_NAME_ABBR  ... CURRENT_RATIO  DEBT_ASSET_RATIO
# 0        688981               中芯国际  ...    166.213586         42.671738
# 1        688096               京源环保  ...    128.966764         64.044384
# 2        688300               联瑞新材  ...    129.159067         59.343309
# 3        688508                芯朋微  ...    472.564938         28.100229
# 4        688026               洁特生物  ...     72.465624         34.057943
#
# [5 rows x 8 columns]
# scrapping data in page 2
# sample page 2 data
#   SECURITY_CODE SECURITY_NAME_ABBR  ... CURRENT_RATIO  DEBT_ASSET_RATIO
# 0        688181               八亿时空  ...    293.144366         15.858293
# 1        688360               德马科技  ...     87.327233         92.158283
# 2        688106               金宏气体  ...     86.011710         64.546040
# 3        688579               山大地纬  ...    260.560617         44.411917
# 4        688122               西部超导  ...    118.288565         66.255340
#
# [5 rows x 8 columns]
# scrapping data in page 3
# scrapping data in page 4
# sample year 2013 data
#   SECURITY_CODE SECURITY_NAME_ABBR  ... CURRENT_RATIO  DEBT_ASSET_RATIO
# 0        688981               中芯国际  ...    166.213586         42.671738
# 1        688096               京源环保  ...    128.966764         64.044384
# 2        688300               联瑞新材  ...    129.159067         59.343309
# 3        688508                芯朋微  ...    472.564938         28.100229
# 4        688026               洁特生物  ...     72.465624         34.057943
#
# [5 rows x 8 columns]
# scrapping year 2014 data
# scrapping data in page 1
# sample page 1 data
#   SECURITY_CODE SECURITY_NAME_ABBR  ... CURRENT_RATIO  DEBT_ASSET_RATIO
# 0        688981               中芯国际  ...    199.806736         42.667625
# 1        688390                固德威  ...    113.737961         78.980426
# 2        688096               京源环保  ...    125.257148         70.051191
# 3        688388               嘉元科技  ...     42.543040         50.881302
# 4        688168                安博通  ...    339.508452         28.996545
#
# [5 rows x 8 columns]
# scrapping data in page 2
# sample page 2 data
#   SECURITY_CODE SECURITY_NAME_ABBR  ... CURRENT_RATIO  DEBT_ASSET_RATIO
# 0        688080                映翰通  ...    430.286600         23.126298
# 1        688078               龙软科技  ...    339.123637         27.613837
# 2        688556               高测股份  ...    116.054754         68.515313
# 3        688181               八亿时空  ...    213.350323         31.853401
# 4        688360               德马科技  ...    104.062733         77.216333
#
# [5 rows x 8 columns]
# scrapping data in page 3
# scrapping data in page 4
# sample year 2014 data
#   SECURITY_CODE SECURITY_NAME_ABBR  ... CURRENT_RATIO  DEBT_ASSET_RATIO
# 0        688981               中芯国际  ...    199.806736         42.667625
# 1        688390                固德威  ...    113.737961         78.980426
# 2        688096               京源环保  ...    125.257148         70.051191
# 3        688388               嘉元科技  ...     42.543040         50.881302
# 4        688168                安博通  ...    339.508452         28.996545
#
# [5 rows x 8 columns]
# scrapping year 2015 data
# scrapping data in page 1
# sample page 1 data
#   SECURITY_CODE SECURITY_NAME_ABBR  ... CURRENT_RATIO  DEBT_ASSET_RATIO
# 0        688095               福昕软件  ...    128.798671         45.385295
# 1        688579               山大地纬  ...    197.105385         53.681056
# 2        688556               高测股份  ...    203.486491         36.105915
# 3        688096               京源环保  ...    176.795366         52.503276
# 4        688518               联赢激光  ...    166.618057         59.107919
#
# [5 rows x 8 columns]
# scrapping data in page 2
# sample page 2 data
#   SECURITY_CODE SECURITY_NAME_ABBR  ... CURRENT_RATIO  DEBT_ASSET_RATIO
# 0        688086               紫晶存储  ...    131.946228         56.045965
# 1        688335               复洁环保  ...    136.522701         56.245374
# 2        688299               长阳科技  ...     79.369913         79.445054
# 3        688357               建龙微纳  ...     40.986471         89.353189
# 4        688078               龙软科技  ...    272.433901         32.964770
#
# [5 rows x 8 columns]
# scrapping data in page 3
# scrapping data in page 4
# sample year 2015 data
#   SECURITY_CODE SECURITY_NAME_ABBR  ... CURRENT_RATIO  DEBT_ASSET_RATIO
# 0        688095               福昕软件  ...    128.798671         45.385295
# 1        688579               山大地纬  ...    197.105385         53.681056
# 2        688556               高测股份  ...    203.486491         36.105915
# 3        688096               京源环保  ...    176.795366         52.503276
# 4        688518               联赢激光  ...    166.618057         59.107919
#
# [5 rows x 8 columns]
# scrapping year 2016 data
# scrapping data in page 1
# sample page 1 data
#   SECURITY_CODE SECURITY_NAME_ABBR  ... CURRENT_RATIO  DEBT_ASSET_RATIO
# 0        688566                吉贝尔  ...    341.523956         24.680233
# 1        688599               天合光能  ...    123.585414         75.561154
# 2        688520               神州细胞  ...    110.185810         80.938000
# 3        688312               燕麦科技  ...   1276.554668          7.586574
# 4        688518               联赢激光  ...    155.272058         63.808517
#
# [5 rows x 8 columns]
# scrapping data in page 2
# sample page 2 data
#   SECURITY_CODE SECURITY_NAME_ABBR  ... CURRENT_RATIO  DEBT_ASSET_RATIO
# 0        688318               财富趋势  ...    707.279114         12.927986
# 1        688155               先惠技术  ...    239.107230         42.768423
# 2        688600               皖仪科技  ...    230.976631         48.621136
# 3        688508                芯朋微  ...    404.024244         25.740948
# 4        688311               盟升电子  ...    457.339028         16.680311
#
# [5 rows x 8 columns]
# scrapping data in page 3
# sample page 3 data
#   SECURITY_CODE SECURITY_NAME_ABBR  ... CURRENT_RATIO  DEBT_ASSET_RATIO
# 0        688166               博瑞医药  ...    127.495576         42.699049
# 1        688138               清溢光电  ...    329.665586         14.695194
# 2        688021               奥福环保  ...    111.082561         53.423777
# 3        688363               华熙生物  ...    256.230368         25.147262
# 4        688299               长阳科技  ...     56.013503         81.207615
#
# [5 rows x 8 columns]
# scrapping data in page 4
# sample page 4 data
#   SECURITY_CODE SECURITY_NAME_ABBR  ... CURRENT_RATIO  DEBT_ASSET_RATIO
# 0        688007               光峰科技  ...    124.631272         81.786720
# 1        688005               容百科技  ...    112.610076         69.919131
# 2        688008               澜起科技  ...    489.699611         21.253080
# 3        688006               杭可科技  ...    147.282934         61.189887
# 4        688003               天准科技  ...    362.959575         20.281997
#
# [5 rows x 8 columns]
# sample year 2016 data
#   SECURITY_CODE SECURITY_NAME_ABBR  ... CURRENT_RATIO  DEBT_ASSET_RATIO
# 0        688566                吉贝尔  ...    341.523956         24.680233
# 1        688599               天合光能  ...    123.585414         75.561154
# 2        688520               神州细胞  ...    110.185810         80.938000
# 3        688312               燕麦科技  ...   1276.554668          7.586574
# 4        688518               联赢激光  ...    155.272058         63.808517
#
# [5 rows x 8 columns]
# scrapping year 2017 data
# scrapping data in page 1
# sample page 1 data
#   SECURITY_CODE SECURITY_NAME_ABBR  ... CURRENT_RATIO  DEBT_ASSET_RATIO
# 0        688577               浙海德曼  ...    117.151650         58.820559
# 1        688056               莱伯泰科  ...    240.050617         35.785722
# 2        688550               瑞联新材  ...    133.341039         48.102730
# 3        688513               苑东生物  ...    313.092219         24.781131
# 4        688017               绿的谐波  ...    413.218898         19.111289
#
# [5 rows x 8 columns]
# scrapping data in page 2
# sample page 2 data
#   SECURITY_CODE SECURITY_NAME_ABBR  ... CURRENT_RATIO  DEBT_ASSET_RATIO
# 0        688600               皖仪科技  ...    199.020589         42.814314
# 1        688579               山大地纬  ...    367.673422         24.640664
# 2        688567               孚能科技  ...    101.921867         81.149308
# 3        688528               秦川物联  ...    156.592269         36.272467
# 4        688180               君实生物  ...    880.004159          8.229392
#
# [5 rows x 8 columns]
# scrapping data in page 3
# sample page 3 data
#   SECURITY_CODE SECURITY_NAME_ABBR  ... CURRENT_RATIO  DEBT_ASSET_RATIO
# 0        688178                万德斯  ...    216.318226         40.224900
# 1        688181               八亿时空  ...    208.366276         28.438732
# 2        688081               兴图新科  ...    243.899728         39.173378
# 3        688078               龙软科技  ...    282.283110         33.038084
# 4        688268               华特气体  ...    221.414271         29.167562
#
# [5 rows x 8 columns]
# scrapping data in page 4
# sample page 4 data
#   SECURITY_CODE SECURITY_NAME_ABBR  ... CURRENT_RATIO  DEBT_ASSET_RATIO
# 0        688033               天宜上佳  ...   1092.014249          7.067444
# 1        688028                沃尔德  ...    466.641013         10.731091
# 2        688022               瀚川智能  ...    130.532003         62.852296
# 3        688020               方邦股份  ...   1426.627836          5.568665
# 4        688015               交控科技  ...    128.814047         76.856618
#
# [5 rows x 8 columns]
# sample year 2017 data
#   SECURITY_CODE SECURITY_NAME_ABBR  ... CURRENT_RATIO  DEBT_ASSET_RATIO
# 0        688577               浙海德曼  ...    117.151650         58.820559
# 1        688056               莱伯泰科  ...    240.050617         35.785722
# 2        688550               瑞联新材  ...    133.341039         48.102730
# 3        688513               苑东生物  ...    313.092219         24.781131
# 4        688017               绿的谐波  ...    413.218898         19.111289
#
# [5 rows x 8 columns]
# scrapping year 2018 data
# scrapping data in page 1
# sample page 1 data
#   SECURITY_CODE SECURITY_NAME_ABBR  ... CURRENT_RATIO  DEBT_ASSET_RATIO
# 0        688577               浙海德曼  ...    148.770053         45.497598
# 1        688056               莱伯泰科  ...    285.273674         30.555915
# 2        688550               瑞联新材  ...    117.432456         54.359310
# 3        688513               苑东生物  ...    274.324324         26.276082
# 4        688017               绿的谐波  ...    881.194572         10.100415
#
# [5 rows x 8 columns]
# scrapping data in page 2
# sample page 2 data
#   SECURITY_CODE SECURITY_NAME_ABBR  ... CURRENT_RATIO  DEBT_ASSET_RATIO
# 0        688277                天智航  ...    581.968520         15.399391
# 1        688600               皖仪科技  ...    207.196798         42.254470
# 2        688579               山大地纬  ...    327.865924         24.981270
# 3        688567               孚能科技  ...    378.850980         25.118043
# 4        688528               秦川物联  ...    139.938558         36.727704
#
# [5 rows x 8 columns]
# scrapping data in page 3
# sample page 3 data
#   SECURITY_CODE SECURITY_NAME_ABBR  ... CURRENT_RATIO  DEBT_ASSET_RATIO
# 0        688099               晶晨股份  ...    248.469665         31.598409
# 1        688088               虹软科技  ...    676.840857         15.564137
# 2        688081               兴图新科  ...    337.553021         28.175019
# 3        688058                宝兰德  ...    756.214640         12.077485
# 4        688036               传音控股  ...    156.477674         62.117824
#
# [5 rows x 8 columns]
# scrapping data in page 4
# sample page 4 data
#   SECURITY_CODE SECURITY_NAME_ABBR  ... CURRENT_RATIO  DEBT_ASSET_RATIO
# 0        688166               博瑞医药  ...    533.354607         12.055174
# 1        688101                三达膜  ...    138.516091         39.571042
# 2        688015               交控科技  ...    121.597267         80.712604
# 3        688222               成都先导  ...    350.658987         23.904312
# 4        688002               睿创微纳  ...    687.313587         15.552859
#
# [5 rows x 8 columns]
# sample year 2018 data
#   SECURITY_CODE SECURITY_NAME_ABBR  ... CURRENT_RATIO  DEBT_ASSET_RATIO
# 0        688577               浙海德曼  ...    148.770053         45.497598
# 1        688056               莱伯泰科  ...    285.273674         30.555915
# 2        688550               瑞联新材  ...    117.432456         54.359310
# 3        688513               苑东生物  ...    274.324324         26.276082
# 4        688017               绿的谐波  ...    881.194572         10.100415
#
# [5 rows x 8 columns]
# scrapping year 2019 data
# scrapping data in page 1
# sample page 1 data
#   SECURITY_CODE SECURITY_NAME_ABBR  ... CURRENT_RATIO  DEBT_ASSET_RATIO
# 0        688599               天合光能  ...    114.480880         65.001743
# 1        688577               浙海德曼  ...    157.225896         42.136083
# 2        688566                吉贝尔  ...    561.484295         21.013085
# 3        688555               泽达易盛  ...    553.181436         17.899095
# 4        688369               致远互联  ...    361.154742         26.977277
#
# [5 rows x 8 columns]
# scrapping data in page 2
# sample page 2 data
#   SECURITY_CODE SECURITY_NAME_ABBR  ... CURRENT_RATIO  DEBT_ASSET_RATIO
# 0        688022               瀚川智能  ...    375.778388         23.424394
# 1        688003               天准科技  ...    673.344920         13.887096
# 2        688399               硕世生物  ...    944.954037         11.571149
# 3        688365               光云科技  ...    744.087598         12.949465
# 4        688222               成都先导  ...    668.157747         19.450760
#
# [5 rows x 8 columns]
# scrapping data in page 3
# sample page 3 data
#   SECURITY_CODE SECURITY_NAME_ABBR  ... CURRENT_RATIO  DEBT_ASSET_RATIO
# 0        688008               澜起科技  ...   2745.226547          5.796728
# 1        688596               正帆科技  ...    138.782203         60.548827
# 2        688378                奥来德  ...    176.737174         45.314900
# 3        688335               复洁环保  ...    231.012435         40.476936
# 4        688188               柏楚电子  ...   3787.545453          3.172267
#
# [5 rows x 8 columns]
# scrapping data in page 4
# sample page 4 data
#   SECURITY_CODE SECURITY_NAME_ABBR  ... CURRENT_RATIO  DEBT_ASSET_RATIO
# 0        688518               联赢激光  ...    208.855381         45.146084
# 1        688520               神州细胞  ...    113.699908         95.693581
# 2        688360               德马科技  ...    169.456581         51.044737
# 3        688366               昊海生科  ...   1096.041961          8.103502
# 4        688268               华特气体  ...    518.607221         15.844455
#
# [5 rows x 8 columns]
# sample year 2019 data
#   SECURITY_CODE SECURITY_NAME_ABBR  ... CURRENT_RATIO  DEBT_ASSET_RATIO
# 0        688599               天合光能  ...    114.480880         65.001743
# 1        688577               浙海德曼  ...    157.225896         42.136083
# 2        688566                吉贝尔  ...    561.484295         21.013085
# 3        688555               泽达易盛  ...    553.181436         17.899095
# 4        688369               致远互联  ...    361.154742         26.977277
#
# [5 rows x 8 columns]
# sample 2010-2019 data
#   SECURITY_CODE SECURITY_NAME_ABBR  ... DEBT_ASSET_RATIO  year
# 0        688519               南亚新材  ...        65.894938  2010
# 1        688336               三生国健  ...         6.621437  2010
# 2        688366               昊海生科  ...        17.640608  2010
# 3        688199               久日新材  ...        31.233680  2010
# 4        688318               财富趋势  ...        12.219895  2010
#
# [5 rows x 9 columns]
# scrapping income statement data
# scrapping year 2010 data
# scrapping data in page 1
# sample page 1 data
#   SECURITY_CODE  PARENT_NETPROFIT  TOTAL_OPERATE_INCOME  OPERATE_PROFIT_RATIO
# 0        688366      5.525172e+07          1.463647e+08             65.868476
# 1        688199      1.635962e+07          1.212591e+08                   NaN
# 2        688318      6.142088e+07          7.634359e+07             39.491513
# 3        688122      7.747011e+07          4.148383e+08             21.766270
# 4        688336      1.565115e+08          3.429396e+08             64.738145
# scrapping data in page 2
# scrapping data in page 3
# scrapping data in page 4
# sample year 2010 data
#   SECURITY_CODE  PARENT_NETPROFIT  TOTAL_OPERATE_INCOME  OPERATE_PROFIT_RATIO
# 0        688366      5.525172e+07          1.463647e+08             65.868476
# 1        688199      1.635962e+07          1.212591e+08                   NaN
# 2        688318      6.142088e+07          7.634359e+07             39.491513
# 3        688122      7.747011e+07          4.148383e+08             21.766270
# 4        688336      1.565115e+08          3.429396e+08             64.738145
# scrapping year 2011 data
# scrapping data in page 1
# sample page 1 data
#   SECURITY_CODE  PARENT_NETPROFIT  TOTAL_OPERATE_INCOME  OPERATE_PROFIT_RATIO
# 0        688393       27150000.00          8.771890e+07                   NaN
# 1        688377       40286198.22          3.540725e+08                   NaN
# 2        688196       63969968.86          5.429296e+08                   NaN
# 3        688318       70759200.00          8.943000e+07              14.90945
# 4        688078       18671265.09          7.941286e+07                   NaN
# scrapping data in page 2
# scrapping data in page 3
# scrapping data in page 4
# sample year 2011 data
#   SECURITY_CODE  PARENT_NETPROFIT  TOTAL_OPERATE_INCOME  OPERATE_PROFIT_RATIO
# 0        688393       27150000.00          8.771890e+07                   NaN
# 1        688377       40286198.22          3.540725e+08                   NaN
# 2        688196       63969968.86          5.429296e+08                   NaN
# 3        688318       70759200.00          8.943000e+07              14.90945
# 4        688078       18671265.09          7.941286e+07                   NaN
# scrapping year 2012 data
# scrapping data in page 1
# sample page 1 data
#   SECURITY_CODE  PARENT_NETPROFIT  TOTAL_OPERATE_INCOME  OPERATE_PROFIT_RATIO
# 0        688056       25026651.41          1.888648e+08                   NaN
# 1        688138       22219764.47          2.585467e+08                   NaN
# 2        688589       19174100.00          9.659440e+07                   NaN
# 3        688208       56876100.00          1.768212e+08                   NaN
# 4        688398       22396080.73          1.341335e+08                   NaN
# scrapping data in page 2
# scrapping data in page 3
# scrapping data in page 4
# sample year 2012 data
#   SECURITY_CODE  PARENT_NETPROFIT  TOTAL_OPERATE_INCOME  OPERATE_PROFIT_RATIO
# 0        688056       25026651.41          1.888648e+08                   NaN
# 1        688138       22219764.47          2.585467e+08                   NaN
# 2        688589       19174100.00          9.659440e+07                   NaN
# 3        688208       56876100.00          1.768212e+08                   NaN
# 4        688398       22396080.73          1.341335e+08                   NaN
# scrapping year 2013 data
# scrapping data in page 1
# sample page 1 data
#   SECURITY_CODE  PARENT_NETPROFIT  TOTAL_OPERATE_INCOME  OPERATE_PROFIT_RATIO
# 0        688981      1.731770e+08          2.068964e+09                   NaN
# 1        688096      8.935881e+05          2.531208e+07            121.351425
# 2        688300      1.423983e+07          1.204986e+08              8.538937
# 3        688026      1.355593e+07          7.002347e+07                   NaN
# 4        688229      5.390883e+06          2.337531e+07                   NaN
# scrapping data in page 2
# sample page 2 data
#   SECURITY_CODE  PARENT_NETPROFIT  TOTAL_OPERATE_INCOME  OPERATE_PROFIT_RATIO
# 0        688360        8917453.03          3.191893e+08            343.763629
# 1        688508       18449178.43          1.582997e+08            138.094710
# 2        688106       61340968.76          4.425125e+08             65.576130
# 3        688579       30493629.03          2.019354e+08            125.691066
# 4        688122       61238143.99          6.654624e+08            -41.892001
# scrapping data in page 3
# scrapping data in page 4
# sample year 2013 data
#   SECURITY_CODE  PARENT_NETPROFIT  TOTAL_OPERATE_INCOME  OPERATE_PROFIT_RATIO
# 0        688981      1.731770e+08          2.068964e+09                   NaN
# 1        688096      8.935881e+05          2.531208e+07            121.351425
# 2        688300      1.423983e+07          1.204986e+08              8.538937
# 3        688026      1.355593e+07          7.002347e+07                   NaN
# 4        688229      5.390883e+06          2.337531e+07                   NaN
# scrapping year 2014 data
# scrapping data in page 1
# sample page 1 data
#   SECURITY_CODE  PARENT_NETPROFIT  TOTAL_OPERATE_INCOME  OPERATE_PROFIT_RATIO
# 0        688981      1.529690e+08          1.969966e+09            -30.382656
# 1        688390      2.058671e+06          1.035614e+08            115.694544
# 2        688096      1.559671e+06          3.955567e+07            372.001589
# 3        688388      1.079887e+07          3.162641e+08            169.797526
# 4        688168      4.416858e+06          4.712073e+07                   NaN
# scrapping data in page 2
# sample page 2 data
#   SECURITY_CODE  PARENT_NETPROFIT  TOTAL_OPERATE_INCOME  OPERATE_PROFIT_RATIO
# 0        688080        4339160.00          6.503509e+07           -135.084861
# 1        688078        8714667.70          7.310235e+07            -86.748519
# 2        688556        8264618.01          6.885262e+07           4520.511934
# 3        688181        8714586.22          6.076381e+07            -31.070250
# 4        688360       13482615.75          3.601040e+08            132.539313
# scrapping data in page 3
# scrapping data in page 4
# sample year 2014 data
#   SECURITY_CODE  PARENT_NETPROFIT  TOTAL_OPERATE_INCOME  OPERATE_PROFIT_RATIO
# 0        688981      1.529690e+08          1.969966e+09            -30.382656
# 1        688390      2.058671e+06          1.035614e+08            115.694544
# 2        688096      1.559671e+06          3.955567e+07            372.001589
# 3        688388      1.079887e+07          3.162641e+08            169.797526
# 4        688168      4.416858e+06          4.712073e+07                   NaN
# scrapping year 2015 data
# scrapping data in page 1
# sample page 1 data
#   SECURITY_CODE  PARENT_NETPROFIT  TOTAL_OPERATE_INCOME  OPERATE_PROFIT_RATIO
# 0        688095       38686533.06          1.409257e+08            -18.960960
# 1        688579       47820088.67          2.938467e+08             46.096420
# 2        688556        1196261.29          6.491357e+07            -67.933083
# 3        688096       11148195.23          5.911164e+07            539.148866
# 4        688518       51655741.39          2.655351e+08            172.629622
# scrapping data in page 2
# sample page 2 data
#   SECURITY_CODE  PARENT_NETPROFIT  TOTAL_OPERATE_INCOME  OPERATE_PROFIT_RATIO
# 0        688309        3685871.25          1.321067e+07            -70.735999
# 1        688215        5962447.78          5.174440e+07            731.976567
# 2        688086       36644698.67          1.276574e+08            572.339630
# 3        688335        2401979.38          4.465407e+07            189.502451
# 4        688299        3871603.08          2.498609e+08            102.455662
# scrapping data in page 3
# scrapping data in page 4
# sample year 2015 data
#   SECURITY_CODE  PARENT_NETPROFIT  TOTAL_OPERATE_INCOME  OPERATE_PROFIT_RATIO
# 0        688095       38686533.06          1.409257e+08            -18.960960
# 1        688579       47820088.67          2.938467e+08             46.096420
# 2        688556        1196261.29          6.491357e+07            -67.933083
# 3        688096       11148195.23          5.911164e+07            539.148866
# 4        688518       51655741.39          2.655351e+08            172.629622
# scrapping year 2016 data
# scrapping data in page 1
# sample page 1 data
#   SECURITY_CODE  PARENT_NETPROFIT  TOTAL_OPERATE_INCOME  OPERATE_PROFIT_RATIO
# 0        688566      7.693968e+07          4.444235e+08                   NaN
# 1        688599      4.791068e+08          2.259389e+10                   NaN
# 2        688520     -1.214295e+07          9.812582e+07                   NaN
# 3        688312      9.234015e+07          2.235183e+08                   NaN
# 4        688518      6.855316e+07          4.162033e+08             30.408452
# scrapping data in page 2
# sample page 2 data
#   SECURITY_CODE  PARENT_NETPROFIT  TOTAL_OPERATE_INCOME  OPERATE_PROFIT_RATIO
# 0        688318      1.387106e+08          1.794455e+08             13.733751
# 1        688155      2.663153e+07          1.782199e+08                   NaN
# 2        688600      3.058987e+07          1.947649e+08                   NaN
# 3        688508      3.005125e+07          2.295342e+08             98.445875
# 4        688311      1.591479e+07          1.458416e+08                   NaN
# scrapping data in page 3
# sample page 3 data
#   SECURITY_CODE  PARENT_NETPROFIT  TOTAL_OPERATE_INCOME  OPERATE_PROFIT_RATIO
# 0        688166      1.706097e+07          2.009248e+08                   NaN
# 1        688138      4.573595e+07          3.146632e+08            -28.842238
# 2        688021      6.124718e+06          9.286866e+07                   NaN
# 3        688363      2.694290e+08          7.331226e+08                   NaN
# 4        688299      2.674397e+07          3.803774e+08           1449.347874
# scrapping data in page 4
# sample page 4 data
#   SECURITY_CODE  PARENT_NETPROFIT  TOTAL_OPERATE_INCOME  OPERATE_PROFIT_RATIO
# 0        688007       13943617.40          3.549547e+08                   NaN
# 1        688005        6877015.78          8.851923e+08                   NaN
# 2        688008       92804284.98          8.449446e+08                   NaN
# 3        688006       89706630.71          4.102153e+08             42.773315
# 4        688003       31489793.47          1.808496e+08             -9.455311
# sample year 2016 data
#   SECURITY_CODE  PARENT_NETPROFIT  TOTAL_OPERATE_INCOME  OPERATE_PROFIT_RATIO
# 0        688566      7.693968e+07          4.444235e+08                   NaN
# 1        688599      4.791068e+08          2.259389e+10                   NaN
# 2        688520     -1.214295e+07          9.812582e+07                   NaN
# 3        688312      9.234015e+07          2.235183e+08                   NaN
# 4        688518      6.855316e+07          4.162033e+08             30.408452
# scrapping year 2017 data
# scrapping data in page 1
# sample page 1 data
#   SECURITY_CODE  PARENT_NETPROFIT  TOTAL_OPERATE_INCOME  OPERATE_PROFIT_RATIO
# 0        688577       36628562.52          3.331508e+08            415.416303
# 1        688056       49071041.52          3.220819e+08             25.010054
# 2        688550       78008660.92          7.191041e+08             40.865369
# 3        688513       64365623.71          4.763380e+08             88.416818
# 4        688017       48586338.44          1.757021e+08                   NaN
# scrapping data in page 2
# sample page 2 data
#   SECURITY_CODE  PARENT_NETPROFIT  TOTAL_OPERATE_INCOME  OPERATE_PROFIT_RATIO
# 0        688277       21669460.85          7.329475e+07            138.345296
# 1        688600       49244696.36          2.837548e+08            450.623056
# 2        688579       61735954.01          3.169059e+08             91.970777
# 3        688567       18261332.45          1.338614e+09           2710.638608
# 4        688528        9799252.08          1.611262e+08            -53.527026
# scrapping data in page 3
# sample page 3 data
#   SECURITY_CODE  PARENT_NETPROFIT  TOTAL_OPERATE_INCOME  OPERATE_PROFIT_RATIO
# 0        688100      1.487450e+08          9.950934e+08            120.256271
# 1        688178      6.975418e+07          2.825464e+08            398.091562
# 2        688181      5.334392e+07          2.307539e+08            284.447726
# 3        688081      3.115335e+07          1.488448e+08           1536.319395
# 4        688078      2.160189e+07          1.072690e+08            691.904787
# scrapping data in page 4
# sample page 4 data
#   SECURITY_CODE  PARENT_NETPROFIT  TOTAL_OPERATE_INCOME  OPERATE_PROFIT_RATIO
# 0        688066      4.759613e+07          2.963474e+08             50.284345
# 1        688033      2.219309e+08          5.071340e+08             13.520881
# 2        688028      5.814118e+07          2.334644e+08             49.258761
# 3        688022      3.219676e+07          2.438491e+08            701.796539
# 4        688020      9.629105e+07          2.262545e+08             22.218141
# sample year 2017 data
#   SECURITY_CODE  PARENT_NETPROFIT  TOTAL_OPERATE_INCOME  OPERATE_PROFIT_RATIO
# 0        688577       36628562.52          3.331508e+08            415.416303
# 1        688056       49071041.52          3.220819e+08             25.010054
# 2        688550       78008660.92          7.191041e+08             40.865369
# 3        688513       64365623.71          4.763380e+08             88.416818
# 4        688017       48586338.44          1.757021e+08                   NaN
# scrapping year 2018 data
# scrapping data in page 1
# sample page 1 data
#   SECURITY_CODE  PARENT_NETPROFIT  TOTAL_OPERATE_INCOME  OPERATE_PROFIT_RATIO
# 0        688577      5.766265e+07          4.273634e+08             56.138655
# 1        688056      5.981613e+07          3.500552e+08              2.072280
# 2        688550      9.464213e+07          8.565672e+08             18.710896
# 3        688513      1.350201e+08          7.687586e+08            100.808079
# 4        688017      6.506691e+07          2.195340e+08             28.067111
# scrapping data in page 2
# sample page 2 data
#   SECURITY_CODE  PARENT_NETPROFIT  TOTAL_OPERATE_INCOME  OPERATE_PROFIT_RATIO
# 0        688277        -855977.97          1.267220e+08           -163.966070
# 1        688600       52036636.12          3.264673e+08             -4.068023
# 2        688579       82253499.60          4.061744e+08             31.074281
# 3        688567      -78214828.30          2.275652e+09           -665.947090
# 4        688528       44369396.55          2.026915e+08            246.999364
# scrapping data in page 3
# sample page 3 data
#   SECURITY_CODE  PARENT_NETPROFIT  TOTAL_OPERATE_INCOME  OPERATE_PROFIT_RATIO
# 0        688099      2.825309e+08          2.369069e+09            189.926851
# 1        688088      1.575518e+08          4.580713e+08            140.722478
# 2        688081      4.221376e+07          1.981364e+08             35.811168
# 3        688058      5.144752e+07          1.223700e+08             52.733428
# 4        688036      6.573780e+08          2.264588e+10              6.047248
# scrapping data in page 4
# sample page 4 data
#   SECURITY_CODE  PARENT_NETPROFIT  TOTAL_OPERATE_INCOME  OPERATE_PROFIT_RATIO
# 0        688166      7.320204e+07          4.075033e+08             66.371935
# 1        688101      1.813217e+08          5.899088e+08             -0.881621
# 2        688015      6.639520e+07          1.162520e+09             44.218660
# 3        688222      4.496049e+07          1.511960e+08            267.763022
# 4        688002      1.251681e+08          3.841047e+08            107.917430
# sample year 2018 data
#   SECURITY_CODE  PARENT_NETPROFIT  TOTAL_OPERATE_INCOME  OPERATE_PROFIT_RATIO
# 0        688577      5.766265e+07          4.273634e+08             56.138655
# 1        688056      5.981613e+07          3.500552e+08              2.072280
# 2        688550      9.464213e+07          8.565672e+08             18.710896
# 3        688513      1.350201e+08          7.687586e+08            100.808079
# 4        688017      6.506691e+07          2.195340e+08             28.067111
# scrapping year 2019 data
# scrapping data in page 1
# sample page 1 data
#   SECURITY_CODE  PARENT_NETPROFIT  TOTAL_OPERATE_INCOME  OPERATE_PROFIT_RATIO
# 0        688577      4.559823e+07          3.847362e+08            -21.336483
# 1        688056      6.132360e+07          3.805185e+08             14.922894
# 2        688550      1.484645e+08          9.902292e+08             61.029928
# 3        688513      1.086116e+08          9.472352e+08            -23.068466
# 4        688017      5.847833e+07          1.859010e+08            -14.031144
# scrapping data in page 2
# sample page 2 data
#   SECURITY_CODE  PARENT_NETPROFIT  TOTAL_OPERATE_INCOME  OPERATE_PROFIT_RATIO
# 0        688277     -3.095783e+07          2.295642e+08           -387.804747
# 1        688600      6.650489e+07          4.090340e+08             23.769839
# 2        688579      7.817663e+07          4.885705e+08             -5.444419
# 3        688567      1.312277e+08          2.449629e+09            226.483337
# 4        688528      4.422946e+07          2.449405e+08             -3.441565
# scrapping data in page 3
# sample page 3 data
#   SECURITY_CODE  PARENT_NETPROFIT  TOTAL_OPERATE_INCOME  OPERATE_PROFIT_RATIO
# 0        688099      1.580418e+08          2.357733e+09            -43.157154
# 1        688088      2.103666e+08          5.644770e+08              8.243449
# 2        688081      5.188832e+07          2.003716e+08             19.603585
# 3        688058      6.124312e+07          1.433023e+08             17.063940
# 4        688036      1.793303e+09          2.534593e+10            156.045434
# scrapping data in page 4
# sample page 4 data
#   SECURITY_CODE  PARENT_NETPROFIT  TOTAL_OPERATE_INCOME  OPERATE_PROFIT_RATIO
# 0        688166      1.110833e+08          5.031567e+08             48.248804
# 1        688101      2.766679e+08          7.420087e+08             47.697377
# 2        688015      1.272915e+08          1.651775e+09             84.293264
# 3        688222      1.202661e+08          2.641969e+08            171.986538
# 4        688002      2.020659e+08          6.846563e+08             61.244744
# sample year 2019 data
#   SECURITY_CODE  PARENT_NETPROFIT  TOTAL_OPERATE_INCOME  OPERATE_PROFIT_RATIO
# 0        688577      4.559823e+07          3.847362e+08            -21.336483
# 1        688056      6.132360e+07          3.805185e+08             14.922894
# 2        688550      1.484645e+08          9.902292e+08             61.029928
# 3        688513      1.086116e+08          9.472352e+08            -23.068466
# 4        688017      5.847833e+07          1.859010e+08            -14.031144
# sample 2010-2019 data
#   SECURITY_CODE  PARENT_NETPROFIT  ...  OPERATE_PROFIT_RATIO  year
# 0        688366      5.525172e+07  ...             65.868476  2010
# 1        688199      1.635962e+07  ...                   NaN  2010
# 2        688318      6.142088e+07  ...             39.491513  2010
# 3        688122      7.747011e+07  ...             21.766270  2010
# 4        688336      1.565115e+08  ...             64.738145  2010
#
# [5 rows x 5 columns]
# scrapping achievement report data
# scrapping year 2010 data
# scrapping data in page 1
# sample page 1 data
#   SECURITY_CODE  WEIGHTAVG_ROE      XSMLL
# 0        688366          33.09  80.779166
# 1        688199          37.27  24.843563
# 2        688318          47.40  93.188068
# 3        688122            NaN  35.755438
# 4        688336            NaN  91.647343
# scrapping data in page 2
# scrapping data in page 3
# scrapping data in page 4
# sample year 2010 data
#   SECURITY_CODE  WEIGHTAVG_ROE      XSMLL
# 0        688366          33.09  80.779166
# 1        688199          37.27  24.843563
# 2        688318          47.40  93.188068
# 3        688122            NaN  35.755438
# 4        688336            NaN  91.647343
# scrapping year 2011 data
# scrapping data in page 1
# sample page 1 data
#   SECURITY_CODE  WEIGHTAVG_ROE      XSMLL
# 0        688393          78.67  64.927057
# 1        688377          16.06  29.460432
# 2        688196          29.43   7.218870
# 3        688318          33.67  91.949010
# 4        688078          37.17  55.740809
# scrapping data in page 2
# scrapping data in page 3
# scrapping data in page 4
# sample year 2011 data
#   SECURITY_CODE  WEIGHTAVG_ROE      XSMLL
# 0        688393          78.67  64.927057
# 1        688377          16.06  29.460432
# 2        688196          29.43   7.218870
# 3        688318          33.67  91.949010
# 4        688078          37.17  55.740809
# scrapping year 2012 data
# scrapping data in page 1
# sample page 1 data
#   SECURITY_CODE  WEIGHTAVG_ROE      XSMLL
# 0        688056          25.50  48.460884
# 1        688138           9.92  28.982381
# 2        688589          21.96  53.745869
# 3        688208          74.20  66.832371
# 4        688398          17.95  37.701312
# scrapping data in page 2
# scrapping data in page 3
# scrapping data in page 4
# sample year 2012 data
#   SECURITY_CODE  WEIGHTAVG_ROE      XSMLL
# 0        688056          25.50  48.460884
# 1        688138           9.92  28.982381
# 2        688589          21.96  53.745869
# 3        688208          74.20  66.832371
# 4        688398          17.95  37.701312
# scrapping year 2013 data
# scrapping data in page 1
# sample page 1 data
#   SECURITY_CODE  WEIGHTAVG_ROE      XSMLL
# 0        688981            NaN  21.191089
# 1        688096           7.91  28.486086
# 2        688300          13.76  38.874291
# 3        688026          18.01  46.384921
# 4        688229         133.32  80.520373
# scrapping data in page 2
# sample page 2 data
#   SECURITY_CODE  WEIGHTAVG_ROE      XSMLL
# 0        688360          53.03  25.927049
# 1        688508          23.65  33.663982
# 2        688106          27.75  44.011025
# 3        688579          45.50  45.164364
# 4        688122          10.30  29.348296
# scrapping data in page 3
# scrapping data in page 4
# sample year 2013 data
#   SECURITY_CODE  WEIGHTAVG_ROE      XSMLL
# 0        688981            NaN  21.191089
# 1        688096           7.91  28.486086
# 2        688300          13.76  38.874291
# 3        688026          18.01  46.384921
# 4        688229         133.32  80.520373
# scrapping year 2014 data
# scrapping data in page 1
# sample page 1 data
#   SECURITY_CODE  WEIGHTAVG_ROE      XSMLL
# 0        688981            NaN  24.541134
# 1        688390          14.58  40.399814
# 2        688096          13.40  29.809683
# 3        688388           6.91  13.101014
# 4        688168          39.03  75.802791
# scrapping data in page 2
# sample page 2 data
#   SECURITY_CODE  WEIGHTAVG_ROE      XSMLL
# 0        688080          10.81  51.598847
# 1        688078           6.45  48.856295
# 2        688556          31.96  39.321511
# 3        688181           7.00  42.872388
# 4        688360          36.38  26.732819
# scrapping data in page 3
# scrapping data in page 4
# sample year 2014 data
#   SECURITY_CODE  WEIGHTAVG_ROE      XSMLL
# 0        688981            NaN  24.541134
# 1        688390          14.58  40.399814
# 2        688096          13.40  29.809683
# 3        688388           6.91  13.101014
# 4        688168          39.03  75.802791
# scrapping year 2015 data
# scrapping data in page 1
# sample page 1 data
#   SECURITY_CODE  WEIGHTAVG_ROE      XSMLL
# 0        688095          37.70  89.266446
# 1        688579          35.17  38.142263
# 2        688556           2.94  45.478063
# 3        688096          45.62  40.061060
# 4        688518          30.99  51.141275
# scrapping data in page 2
# sample page 2 data
#   SECURITY_CODE  WEIGHTAVG_ROE      XSMLL
# 0        688309          11.01  96.925113
# 1        688215          36.42  39.107445
# 2        688086          44.16  45.144265
# 3        688335          27.46  37.489424
# 4        688299           3.00  26.059410
# scrapping data in page 3
# scrapping data in page 4
# sample year 2015 data
#   SECURITY_CODE  WEIGHTAVG_ROE      XSMLL
# 0        688095          37.70  89.266446
# 1        688579          35.17  38.142263
# 2        688556           2.94  45.478063
# 3        688096          45.62  40.061060
# 4        688518          30.99  51.141275
# scrapping year 2016 data
# scrapping data in page 1
# sample page 1 data
#   SECURITY_CODE  WEIGHTAVG_ROE      XSMLL
# 0        688566          24.18  84.560351
# 1        688599           6.01  19.063325
# 2        688520         -12.00  77.286474
# 3        688312          47.90  66.345764
# 4        688518          24.73  48.338684
# scrapping data in page 2
# sample page 2 data
#   SECURITY_CODE  WEIGHTAVG_ROE      XSMLL
# 0        688318          24.16  88.831707
# 1        688155          45.12  36.787918
# 2        688600          20.43  55.163304
# 3        688508          16.82  34.678528
# 4        688311           7.69  57.631116
# scrapping data in page 3
# sample page 3 data
#   SECURITY_CODE  WEIGHTAVG_ROE      XSMLL
# 0        688166           8.06  57.674538
# 1        688138          11.25  33.455007
# 2        688021           4.10  46.318848
# 3        688363          24.14  77.360861
# 4        688299          15.16  26.990067
# scrapping data in page 4
# sample page 4 data
#   SECURITY_CODE  WEIGHTAVG_ROE      XSMLL
# 0        688007          35.24  32.973316
# 1        688005           3.17  12.099515
# 2        688008          11.35  51.202823
# 3        688006          56.37  45.162881
# 4        688003          16.63  58.005823
# sample year 2016 data
#   SECURITY_CODE  WEIGHTAVG_ROE      XSMLL
# 0        688566          24.18  84.560351
# 1        688599           6.01  19.063325
# 2        688520         -12.00  77.286474
# 3        688312          47.90  66.345764
# 4        688518          24.73  48.338684
# scrapping year 2017 data
# scrapping data in page 1
# sample page 1 data
#   SECURITY_CODE  WEIGHTAVG_ROE      XSMLL
# 0        688577          21.53  36.470200
# 1        688056          19.17  51.979943
# 2        688550          16.65  37.541212
# 3        688513          15.78  85.044636
# 4        688017          17.76  47.083813
# scrapping data in page 2
# sample page 2 data
#   SECURITY_CODE  WEIGHTAVG_ROE      XSMLL
# 0        688277          14.77  67.209677
# 1        688600          28.10  51.238804
# 2        688579          12.76  47.161493
# 3        688567           5.59  16.482912
# 4        688528           6.69  47.815444
# scrapping data in page 3
# sample page 3 data
#   SECURITY_CODE  WEIGHTAVG_ROE      XSMLL
# 0        688100          14.05  35.605502
# 1        688178          57.41  37.584969
# 2        688181          20.49  50.888460
# 3        688081          26.50  66.227771
# 4        688078          17.59  54.199101
# scrapping data in page 4
# sample page 4 data
#   SECURITY_CODE  WEIGHTAVG_ROE      XSMLL
# 0        688066          13.44  59.628323
# 1        688033          22.55  73.122904
# 2        688028          21.04  51.838416
# 3        688022          44.09  37.196049
# 4        688020          32.20  73.173459
# sample year 2017 data
#   SECURITY_CODE  WEIGHTAVG_ROE      XSMLL
# 0        688577          21.53  36.470200
# 1        688056          19.17  51.979943
# 2        688550          16.65  37.541212
# 3        688513          15.78  85.044636
# 4        688017          17.76  47.083813
# scrapping year 2018 data
# scrapping data in page 1
# sample page 1 data
#   SECURITY_CODE  WEIGHTAVG_ROE      XSMLL
# 0        688577          23.77  35.805602
# 1        688056          22.84  48.428385
# 2        688550          17.80  35.039581
# 3        688513          26.35  88.636560
# 4        688017          20.06  48.826327
# scrapping data in page 2
# sample page 2 data
#   SECURITY_CODE  WEIGHTAVG_ROE      XSMLL
# 0        688277          -0.26  76.121892
# 1        688600          24.17  52.642418
# 2        688579          13.23  47.166138
# 3        688567          -1.47   5.586469
# 4        688528          20.12  44.424600
# scrapping data in page 3
# sample page 3 data
#   SECURITY_CODE  WEIGHTAVG_ROE      XSMLL
# 0        688099          28.98  34.811304
# 1        688088          22.85  94.286275
# 2        688081          24.50  70.751243
# 3        688058          35.13  94.980742
# 4        688036          18.49  24.448213
# scrapping data in page 4
# sample page 4 data
#   SECURITY_CODE  WEIGHTAVG_ROE      XSMLL
# 0        688166          15.16  58.453937
# 1        688101          13.63  41.714154
# 2        688015          17.91  26.926537
# 3        688222          36.41  82.661739
# 4        688002          27.61  60.073723
# sample year 2018 data
#   SECURITY_CODE  WEIGHTAVG_ROE      XSMLL
# 0        688577          23.77  35.805602
# 1        688056          22.84  48.428385
# 2        688550          17.80  35.039581
# 3        688513          26.35  88.636560
# 4        688017          20.06  48.826327
# scrapping year 2019 data
# scrapping data in page 1
# sample page 1 data
#   SECURITY_CODE  WEIGHTAVG_ROE      XSMLL
# 0        688577          14.64  34.205215
# 1        688056          18.79  46.311781
# 2        688550          23.39  39.667272
# 3        688513          17.54  90.253176
# 4        688017           9.70  49.372834
# scrapping data in page 2
# sample page 2 data
#   SECURITY_CODE  WEIGHTAVG_ROE      XSMLL
# 0        688277          -5.39  84.947137
# 1        688600          24.12  53.118399
# 2        688579           9.53  45.363024
# 3        688567           1.88  23.492882
# 4        688528          16.40  43.865177
# scrapping data in page 3
# sample page 3 data
#   SECURITY_CODE  WEIGHTAVG_ROE      XSMLL
# 0        688099           9.24  33.928395
# 1        688088          12.67  93.271311
# 2        688081          23.18  77.422480
# 3        688058          19.32  96.457611
# 4        688036          33.53  27.357223
# scrapping data in page 4
# sample page 4 data
#   SECURITY_CODE  WEIGHTAVG_ROE      XSMLL
# 0        688166          12.96  64.044820
# 1        688101          16.40  41.303326
# 2        688015          18.51  26.656726
# 3        688222          26.68  81.548638
# 4        688002          12.79  50.415288
# sample year 2019 data
#   SECURITY_CODE  WEIGHTAVG_ROE      XSMLL
# 0        688577          14.64  34.205215
# 1        688056          18.79  46.311781
# 2        688550          23.39  39.667272
# 3        688513          17.54  90.253176
# 4        688017           9.70  49.372834
# sample 2010-2019 data
#   SECURITY_CODE  WEIGHTAVG_ROE      XSMLL  year
# 0        688366          33.09  80.779166  2010
# 1        688199          37.27  24.843563  2010
# 2        688318          47.40  93.188068  2010
# 3        688122            NaN  35.755438  2010
# 4        688336            NaN  91.647343  2010
# sample combined statements data
#   SECURITY_CODE SECURITY_NAME_ABBR  ... WEIGHTAVG_ROE      XSMLL
# 0        688519               南亚新材  ...           NaN  12.397159
# 1        688336               三生国健  ...           NaN  91.647343
# 2        688366               昊海生科  ...         33.09  80.779166
# 3        688199               久日新材  ...         37.27  24.843563
# 4        688318               财富趋势  ...         47.40  93.188068
#
# [5 rows x 14 columns]

# %%
DfData1 = calculate_indicators(DfData)
DfData2 = normalization(DfData1)
DfData3 = calculate_weights(DfData2)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# calculating year 2010 indicators
# calculating year 2011 indicators
# calculating year 2012 indicators
# calculating year 2013 indicators
# calculating year 2014 indicators
# calculating year 2015 indicators
# calculating year 2016 indicators
# calculating year 2017 indicators
# calculating year 2018 indicators
# calculating year 2019 indicators
# /usr/local/lib/python3.6/dist-packages/xlsxwriter/workbook.py:325: UserWarning: Calling close() on already closed file.
#   warn("Calling close() on already closed file.")
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == '':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   from ipykernel import kernelapp as app

# %%
DfData1
# Out:
#     SECURITY_CODE  ... inventory_turnover
# 0          688366  ...           0.961102
# 0          688199  ...           6.055684
# 1          688366  ...           0.885811
# 0          688078  ...          22.832915
# 1          688080  ...           2.907313
# ..            ...  ...                ...
# 162        688596  ...           1.453089
# 163        688598  ...           1.794481
# 164        688599  ...           3.928877
# 165        688600  ...           1.304134
# 166        688981  ...           3.987335
#
# [510 rows x 10 columns]

# %%
calculate_shang(DfData3)
# Out:
# 1
# 0    inf
# Name: OPERATE_PROFIT_RATIO_normalized, dtype: float64
# inf
# inf
# WEIGHTAVG_ROE_shang_rong: inf
# 2
# 1   -12.588154
# 2     0.000003
# Name: OPERATE_PROFIT_RATIO_normalized, dtype: float64
# -3.9541059181794644e-05
# -5.7045689993072146e-05
# WEIGHTAVG_ROE_shang_rong: 0.9999100056377116
# 10
# 3    -9.505169e-01
# 4    -3.224062e+00
# 5    -1.515577e+01
# 6    -2.548404e+00
# 7     2.617765e-07
# 8    -1.544192e+00
# 9    -1.473609e-01
# 10   -1.755064e+00
# 11   -2.035782e+00
# 12   -2.362082e+00
# Name: OPERATE_PROFIT_RATIO_normalized, dtype: float64
# -1.9436825535888411
# -0.8441306075952552
# WEIGHTAVG_ROE_shang_rong: -0.19058468753278635
# 22
# 13   -1.743691e+00
# 14   -3.595867e+00
# 15   -1.771243e+00
# 16   -1.200664e+00
# 17   -8.597020e-01
# 18   -1.277750e+00
# 19   -1.595494e+01
# 20   -8.203031e-01
# 21   -7.617904e-01
# 22   -5.821918e-01
# 23   -1.779241e+00
# 24   -1.219246e+00
# 25   -2.034339e+00
# 26    1.177214e-07
# 27   -2.199241e+00
# 28   -2.704190e+00
# 29   -1.617367e+00
# 30   -1.462223e+00
# 31   -7.620615e-01
# 32   -8.334654e-01
# 33   -1.483526e+00
# 34   -1.212783e+00
# Name: OPERATE_PROFIT_RATIO_normalized, dtype: float64
# -6.254442196749748
# -2.0234087014736732
# WEIGHTAVG_ROE_shang_rong: -0.8529532202960148
# 49
# 35   -2.409574e+00
# 36   -2.820995e+00
# 37   -3.008102e+00
# 38   -2.650570e+00
# 39   -2.812684e+00
# 40   -1.437703e+00
# 41   -3.149089e+00
# 42   -3.415809e+00
# 43   -2.756458e+00
# 44   -2.839843e+00
# 45   -2.611715e+00
# 46   -1.979114e+00
# 47   -2.655373e+00
# 48   -2.756463e+00
# 49   -2.936979e+00
# 50   -2.410963e+00
# 51   -2.698923e+00
# 52   -2.646380e+00
# 53   -3.090653e+00
# 54   -2.910330e+00
# 55   -5.771772e+00
# 56   -2.711650e+00
# 57   -2.803927e+00
# 58   -3.104031e+00
# 59   -1.851079e+00
# 60   -1.847923e+01
# 61   -2.798263e+00
# 62   -2.719170e+00
# 63   -2.818086e+00
# 64   -2.489047e+00
# 65   -2.086215e+00
# 66   -2.425365e+00
# 67   -2.755270e+00
# 68   -2.880455e+00
# 69   -2.341473e+00
# 70   -2.465733e+00
# 71   -2.941226e+00
# 72   -2.725002e+00
# 73   -2.822371e+00
# 74   -2.371951e+00
# 75   -1.838580e+00
# 76   -2.157343e+00
# 77   -2.143480e+00
# 78    9.431347e-09
# 79   -2.712894e+00
# 80   -2.449946e+00
# 81   -2.856940e+00
# 82   -2.784626e+00
# 83   -2.186720e+00
# Name: OPERATE_PROFIT_RATIO_normalized, dtype: float64
# -8.942859608999955
# -2.297860364555237
# WEIGHTAVG_ROE_shang_rong: -2.8618861855801887
# 61
# 84    -1.376784
# 85    -1.310683
# 86    -1.318611
# 87    -0.883917
# 88    -1.245727
#          ...
# 140   -1.355896
# 141   -1.305900
# 142   -1.298755
# 143   -1.299752
# 144   -1.362618
# Name: OPERATE_PROFIT_RATIO_normalized, Length: 61, dtype: float64
# -20.819024531725926
# -5.064379307077716
# WEIGHTAVG_ROE_shang_rong: -3.8605241444037643
# 59
# 145   -2.000045e+00
# 146   -1.517040e+00
# 147   -1.979841e+00
# 148   -1.698145e+00
# 149   -2.277182e+00
# 150   -1.715645e+00
# 151   -2.564545e+00
# 152   -1.479217e+00
# 153   -1.913856e+00
# 154   -1.466188e+00
# 155   -1.880452e+00
# 156   -1.663720e+00
# 157   -1.778921e+00
# 158   -1.993427e+00
# 159   -1.692623e+00
# 160   -2.232128e+00
# 161   -1.740378e+00
# 162   -1.969384e+00
# 163   -1.927967e+00
# 164   -2.270750e+00
# 165   -1.554482e+00
# 166   -1.885667e+00
# 167   -2.068058e+00
# 168   -1.490130e+00
# 169   -2.540008e+00
# 170    2.083758e-08
# 171   -1.639507e+00
# 172   -1.685845e+00
# 173   -1.820795e+00
# 174   -1.841900e+00
# 175   -1.500965e+00
# 176   -2.086403e+00
# 177   -2.090365e+00
# 178   -2.170520e-01
# 179   -1.775340e+00
# 180   -1.374266e+00
# 181   -2.071887e+00
# 182   -8.075359e-01
# 183   -2.048144e+00
# 184   -1.165987e+00
# 185   -2.165951e+00
# 186   -1.473508e+00
# 187   -3.793456e+00
# 188   -1.926843e+00
# 189   -1.706638e+00
# 190   -1.100716e+00
# 191   -2.027368e+00
# 192   -1.992663e+00
# 193   -1.688192e+00
# 194   -1.986022e+00
# 195   -1.768651e+01
# 196   -1.873236e+00
# 197   -1.625006e+00
# 198   -1.016645e+00
# 199   -1.905818e+00
# 200   -2.033832e+00
# 201   -2.049954e+00
# 202   -2.084357e+00
# 203   -1.793509e+00
# Name: OPERATE_PROFIT_RATIO_normalized, dtype: float64
# -16.355623899304124
# -4.0111523497470785
# WEIGHTAVG_ROE_shang_rong: 0.1802346516219272
# 139
# 204   -0.695225
# 205   -3.654653
# 206   -3.618959
# 207   -3.455956
# 208   -3.935570
#          ...
# 338   -3.876453
# 339   -3.882195
# 340   -3.966584
# 341   -3.269733
# 342   -3.670887
# Name: OPERATE_PROFIT_RATIO_normalized, Length: 139, dtype: float64
# -13.668736070416685
# -2.7700493012321004
# WEIGHTAVG_ROE_shang_rong: -6.995835731488549
# 167
# 343   -1.117134
# 344   -0.970334
# 345   -1.000861
# 346   -1.011685
# 347   -0.659310
#          ...
# 505   -0.972156
# 506   -0.999938
# 507   -1.155942
# 508   -1.126648
# 509   -1.198776
# Name: OPERATE_PROFIT_RATIO_normalized, Length: 167, dtype: float64
# -59.318492987914006
# -11.590184584436487
# WEIGHTAVG_ROE_shang_rong: -8.589449217990143
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: RuntimeWarning: divide by zero encountered in double_scalars
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:10: RuntimeWarning: divide by zero encountered in double_scalars
#   # Remove the CWD from sys.path while we load stuff.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: RuntimeWarning: divide by zero encountered in double_scalars
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:12: RuntimeWarning: divide by zero encountered in double_scalars
#   if sys.path[0] == '':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:13: RuntimeWarning: divide by zero encountered in double_scalars
#   del sys.path[0]
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:14: RuntimeWarning: divide by zero encountered in double_scalars
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:18: RuntimeWarning: divide by zero encountered in double_scalars
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:21: RuntimeWarning: invalid value encountered in double_scalars
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:22: RuntimeWarning: invalid value encountered in double_scalars
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:23: RuntimeWarning: invalid value encountered in double_scalars
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:24: RuntimeWarning: invalid value encountered in double_scalars
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:25: RuntimeWarning: invalid value encountered in double_scalars
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:26: RuntimeWarning: invalid value encountered in double_scalars
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.6/dist-packages/pandas/core/series.py:679: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /usr/local/lib/python3.6/dist-packages/xlsxwriter/workbook.py:325: UserWarning: Calling close() on already closed file.
#   warn("Calling close() on already closed file.")
